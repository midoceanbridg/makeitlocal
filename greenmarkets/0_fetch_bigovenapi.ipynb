# %% [markdown]
# ### Grab data from BigOven API

# %%
import requests
from time import sleep
import os

# %%
mykey = open('eatlocal/generated_data/BOapikey.txt').read().strip()

# %%
#get recipes by ID

mealstage = 'maindish'

def getlistrec(pg, rpp):
    '''A function for getting a list of available recipe IDs''''
    params = {'include_primarycat': mealstage, 'pg': str(pg), 'rpp': str(rpp), 'api_key': mykey}   
    response = requests.get('https://api2.bigoven.com/recipes', params=params)
    return response.json()

params = {'api_key': mykey} 
    

def getrecipes():
    '''Grabs the list of recipe IDs and iteratively downloads each recipe'''
    trackerfile = f'bigoven/{mealstage}/pagegotto.txt' #opening a file to track the number of previously saved recipes
    pg, n = open(trackerfile).read().strip().split(',') 
    pg, n = int(pg), int(n)
    rpp = 250
    while True:
        print(f'Getting list of recipes: {pg} , {rpp}')
        response = getlistrec(pg, rpp) #getting the IDs 
        
        #go through list of IDs, request full recipe, save
        for i, recipemeta in enumerate(response['Results']):
            if i < n: continue 
                
            id = recipemeta['RecipeID']
            response = requests.get(f'https://api2.bigoven.com/recipe/{id}', params=params)
            if "Message" in response.json(): 
                with open(f'bigoven/{mealstage}/regrab.txt', 'a') as fh:
                    fh.write(f'{pg},{i},{id}\n')
                continue
                
                #saving block
            with open(f'bigoven/{mealstage}/{mealstage}-{pg}-{i}-{id}.json', 'a') as fh:
                fh.write(response.text)
            with open(f'bigoven/{mealstage}/pagegotto.new', 'w') as fh:
                fh.write(f'{pg},{i}\n')
            os.rename(f'bigoven/{mealstage}/pagegotto.new', trackerfile)
        pg += 1
        n = 0

while True: #Grab as many recipes as possible
    try:
        getrecipes()
    except Exception as e:
        print(f'Error getting recipes: {e}')
        sleep(60*30) #bigoven throttles by the hour, so when we hit our limit wait 30 mins and try again
# Out:
# Getting list of recipes: 132 , 250
# Getting list of recipes: 133 , 250
# Getting list of recipes: 134 , 250
# Getting list of recipes: 135 , 250
# Getting list of recipes: 136 , 250
# Getting list of recipes: 137 , 250
# Error getting recipes: 'Results'
# Getting list of recipes: 136 , 250
# Getting list of recipes: 137 , 250
# Getting list of recipes: 138 , 250
# Getting list of recipes: 139 , 250
# Getting list of recipes: 140 , 250
# Getting list of recipes: 141 , 250
# Error getting recipes: 'Results'
# Getting list of recipes: 140 , 250
# Error getting recipes: 'Results'
# Getting list of recipes: 140 , 250
# Getting list of recipes: 141 , 250
# Getting list of recipes: 142 , 250
# Getting list of recipes: 143 , 250
# Getting list of recipes: 144 , 250
# Getting list of recipes: 145 , 250
# Error getting recipes: 'Results'
# Getting list of recipes: 144 , 250
# Getting list of recipes: 145 , 250
# Getting list of recipes: 146 , 250
# Getting list of recipes: 147 , 250
# Getting list of recipes: 148 , 250
# Getting list of recipes: 149 , 250
# Error getting recipes: 'Results'
# Getting list of recipes: 148 , 250
# Error getting recipes: 'Results'
# Getting list of recipes: 148 , 250
# Getting list of recipes: 149 , 250
# Getting list of recipes: 150 , 250
# Getting list of recipes: 151 , 250
# Getting list of recipes: 152 , 250
# Getting list of recipes: 153 , 250
# Error getting recipes: 'Results'
# Getting list of recipes: 152 , 250
# Error getting recipes: 'Results'
# Getting list of recipes: 152 , 250
# Getting list of recipes: 153 , 250
# Getting list of recipes: 154 , 250
# Getting list of recipes: 155 , 250
# Getting list of recipes: 156 , 250
# Getting list of recipes: 157 , 250
# Error getting recipes: 'Results'
# Getting list of recipes: 156 , 250
# Getting list of recipes: 157 , 250
# Getting list of recipes: 158 , 250
# Getting list of recipes: 159 , 250
# Getting list of recipes: 160 , 250
# Getting list of recipes: 161 , 250
# Error getting recipes: 'Results'
# Getting list of recipes: 160 , 250
# Getting list of recipes: 161 , 250
# Getting list of recipes: 162 , 250
# Error getting recipes: 'Results'
# Getting list of recipes: 161 , 250
# Getting list of recipes: 162 , 250
# Getting list of recipes: 163 , 250
# Getting list of recipes: 164 , 250
# Getting list of recipes: 165 , 250
# Error getting recipes: 'Results'
# Getting list of recipes: 164 , 250
# Getting list of recipes: 165 , 250
# Getting list of recipes: 166 , 250
# Getting list of recipes: 167 , 250
# Getting list of recipes: 168 , 250
# Getting list of recipes: 169 , 250
# Getting list of recipes: 170 , 250
# Error getting recipes: 'Results'
# Getting list of recipes: 169 , 250
# Error getting recipes: 'Results'
# Getting list of recipes: 169 , 250
# Getting list of recipes: 170 , 250
# Getting list of recipes: 171 , 250
# Getting list of recipes: 172 , 250
# Getting list of recipes: 173 , 250
# Getting list of recipes: 174 , 250
# Error getting recipes: 'Results'
# Getting list of recipes: 173 , 250
# Getting list of recipes: 174 , 250
# Getting list of recipes: 175 , 250
# Getting list of recipes: 176 , 250
# Getting list of recipes: 177 , 250
# Getting list of recipes: 178 , 250
# Error getting recipes: 'Results'
# Getting list of recipes: 177 , 250
# Error getting recipes: 'Results'
# Getting list of recipes: 177 , 250
# Getting list of recipes: 178 , 250
# Getting list of recipes: 179 , 250
# Getting list of recipes: 180 , 250
# Getting list of recipes: 181 , 250
# Getting list of recipes: 182 , 250
# Error getting recipes: 'Results'
# Getting list of recipes: 181 , 250
# Getting list of recipes: 182 , 250
# Getting list of recipes: 183 , 250
# Getting list of recipes: 184 , 250
# Getting list of recipes: 185 , 250
# Getting list of recipes: 186 , 250
# Error getting recipes: 'Results'
# Getting list of recipes: 185 , 250
# Error getting recipes: 'Results'
# Getting list of recipes: 185 , 250
# Getting list of recipes: 186 , 250
# Getting list of recipes: 187 , 250
# Getting list of recipes: 188 , 250
# Getting list of recipes: 189 , 250
# Getting list of recipes: 190 , 250
# Error getting recipes: 'Results'
# Getting list of recipes: 189 , 250
# Error getting recipes: 'Results'
# Getting list of recipes: 189 , 250
# Getting list of recipes: 190 , 250
# Getting list of recipes: 191 , 250
# Getting list of recipes: 192 , 250
# Getting list of recipes: 193 , 250
# Getting list of recipes: 194 , 250
# Error getting recipes: 'Results'
# Getting list of recipes: 193 , 250
# Getting list of recipes: 194 , 250
# Getting list of recipes: 195 , 250
# Getting list of recipes: 196 , 250
# Getting list of recipes: 197 , 250
# Getting list of recipes: 198 , 250
# Error getting recipes: 'Results'
# Getting list of recipes: 197 , 250
# Error getting recipes: 'Results'
# Getting list of recipes: 197 , 250
# Getting list of recipes: 198 , 250
# Getting list of recipes: 199 , 250
# Getting list of recipes: 200 , 250
# Getting list of recipes: 201 , 250
# Getting list of recipes: 202 , 250
# Error getting recipes: 'Results'
# Getting list of recipes: 201 , 250
# Getting list of recipes: 202 , 250
# Getting list of recipes: 203 , 250
# Getting list of recipes: 204 , 250
# Getting list of recipes: 205 , 250
# Getting list of recipes: 206 , 250
# Error getting recipes: 'Results'
# Getting list of recipes: 205 , 250
# Error getting recipes: 'Results'
# Getting list of recipes: 205 , 250
# Getting list of recipes: 206 , 250
# Getting list of recipes: 207 , 250
# Getting list of recipes: 208 , 250
# Getting list of recipes: 209 , 250
# Getting list of recipes: 210 , 250
# Error getting recipes: 'Results'
# Getting list of recipes: 209 , 250
# Error getting recipes: 'Results'
# Getting list of recipes: 209 , 250
# Getting list of recipes: 210 , 250
# Getting list of recipes: 211 , 250
# Getting list of recipes: 212 , 250
# Getting list of recipes: 213 , 250
# Getting list of recipes: 214 , 250
# Getting list of recipes: 215 , 250
# Error getting recipes: 'Results'
# Getting list of recipes: 214 , 250
# Getting list of recipes: 215 , 250
# Getting list of recipes: 216 , 250
# Getting list of recipes: 217 , 250
# Getting list of recipes: 218 , 250
# Error getting recipes: 'Results'
# Getting list of recipes: 217 , 250
# Error getting recipes: 'Results'
# Getting list of recipes: 217 , 250
# Getting list of recipes: 218 , 250
# Getting list of recipes: 219 , 250
# Getting list of recipes: 220 , 250
# Getting list of recipes: 221 , 250
# Getting list of recipes: 222 , 250
# Getting list of recipes: 223 , 250
# Error getting recipes: 'Results'
# Getting list of recipes: 222 , 250
# Getting list of recipes: 223 , 250
# Getting list of recipes: 224 , 250
# Getting list of recipes: 225 , 250
# Getting list of recipes: 226 , 250
# Getting list of recipes: 227 , 250
# Error getting recipes: 'Results'
# Getting list of recipes: 226 , 250
# Error getting recipes: 'Results'
# Getting list of recipes: 226 , 250
# Getting list of recipes: 227 , 250
# Getting list of recipes: 228 , 250
# Getting list of recipes: 229 , 250
# Getting list of recipes: 230 , 250
# Error getting recipes: 'Results'
# Getting list of recipes: 229 , 250
# Getting list of recipes: 230 , 250
# Getting list of recipes: 231 , 250
# Getting list of recipes: 232 , 250
# Getting list of recipes: 233 , 250
# Getting list of recipes: 234 , 250
# Error getting recipes: 'Results'
# Getting list of recipes: 233 , 250
# Getting list of recipes: 234 , 250
# Getting list of recipes: 235 , 250
# Error getting recipes: 'Results'
# Getting list of recipes: 234 , 250
# Getting list of recipes: 235 , 250
# Getting list of recipes: 236 , 250
# Getting list of recipes: 237 , 250
# Getting list of recipes: 238 , 250
# Getting list of recipes: 239 , 250
# Error getting recipes: 'Results'
# Getting list of recipes: 238 , 250
# Error getting recipes: 'Results'
# Getting list of recipes: 238 , 250
# Getting list of recipes: 239 , 250
# Getting list of recipes: 240 , 250
# Getting list of recipes: 241 , 250
# Getting list of recipes: 242 , 250
# Getting list of recipes: 243 , 250
# Error getting recipes: 'Results'
# Getting list of recipes: 242 , 250
# Getting list of recipes: 243 , 250
# Getting list of recipes: 244 , 250
# Getting list of recipes: 245 , 250
# Getting list of recipes: 246 , 250
# Error getting recipes: 'Results'
# Getting list of recipes: 245 , 250
# Getting list of recipes: 246 , 250
# Error getting recipes: 'Results'
# Getting list of recipes: 245 , 250
# Getting list of recipes: 246 , 250
# Getting list of recipes: 247 , 250
# Getting list of recipes: 248 , 250
# Getting list of recipes: 249 , 250
# Getting list of recipes: 250 , 250
# Error getting recipes: 'Results'
# Getting list of recipes: 249 , 250
# Getting list of recipes: 250 , 250
# Getting list of recipes: 251 , 250
# Getting list of recipes: 252 , 250
# Getting list of recipes: 253 , 250
# Getting list of recipes: 254 , 250
# Error getting recipes: 'Results'
# Getting list of recipes: 253 , 250
# Error getting recipes: 'Results'
# Getting list of recipes: 253 , 250
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-41c1e257993d> in <module>
#      40 while True:
#      41     try:
# ---> 42         getrecipes()
#      43     except Exception as e:
#      44         print(f'Error getting recipes: {e}')
#
# <ipython-input-3-41c1e257993d> in getrecipes()
#      18     while True:
#      19         print(f'Getting list of recipes: {pg} , {rpp}')
# ---> 20         response = getlistrec(pg, rpp)
#      21
#      22         for i, recipemeta in enumerate(response['Results']):
#
# <ipython-input-3-41c1e257993d> in getlistrec(pg, rpp)
#       5 def getlistrec(pg, rpp):
#       6     params = {'include_primarycat': mealstage, 'pg': str(pg), 'rpp': str(rpp), 'api_key': mykey}
# ----> 7     response = requests.get('https://api2.bigoven.com/recipes', params=params)
#       8     return response.json()
#       9
#
# /opt/anaconda3/envs/insight/lib/python3.6/site-packages/requests/api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# /opt/anaconda3/envs/insight/lib/python3.6/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# /opt/anaconda3/envs/insight/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# /opt/anaconda3/envs/insight/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# /opt/anaconda3/envs/insight/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# /opt/anaconda3/envs/insight/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     675                 body=body,
#     676                 headers=headers,
# --> 677                 chunked=chunked,
#     678             )
#     679
#
# /opt/anaconda3/envs/insight/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     424                     # Python 3 (including for exceptions like SystemExit).
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     428             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# /opt/anaconda3/envs/insight/lib/python3.6/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# /opt/anaconda3/envs/insight/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     419                 # Python 3
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#     423                     # Remove the TypeError from the exception chain in
#
# /opt/anaconda3/envs/insight/lib/python3.6/http/client.py in getresponse(self)
#    1352         try:
#    1353             try:
# -> 1354                 response.begin()
#    1355             except ConnectionError:
#    1356                 self.close()
#
# /opt/anaconda3/envs/insight/lib/python3.6/http/client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# /opt/anaconda3/envs/insight/lib/python3.6/http/client.py in _read_status(self)
#     266
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#     270             raise LineTooLong("status line")
#
# /opt/anaconda3/envs/insight/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# /opt/anaconda3/envs/insight/lib/python3.6/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     311     def recv_into(self, *args, **kwargs):
#     312         try:
# --> 313             return self.connection.recv_into(*args, **kwargs)
#     314         except OpenSSL.SSL.SysCallError as e:
#     315             if self.suppress_ragged_eofs and e.args == (-1, "Unexpected EOF"):
#
# /opt/anaconda3/envs/insight/lib/python3.6/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1837             result = _lib.SSL_peek(self._ssl, buf, nbytes)
#    1838         else:
# -> 1839             result = _lib.SSL_read(self._ssl, buf, nbytes)
#    1840         self._raise_ssl_error(self._ssl, result)
#    1841
#
# KeyboardInterrupt:
