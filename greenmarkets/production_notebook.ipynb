# %%
import requests
from sklearn.manifold import TSNE
import pickle
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel
import numpy as np
from fuzzywuzzy import fuzz, process

from functools import lru_cache

# %%
#User input!

theurl = 'https://tasty.co/recipe/chicken-veggie-stir-fry'

# %%
#function definiton block
@lru_cache
def load_data():
    w2vm = pickle.load(open("bigoven/w2vmodel.pkl", 'rb'))
    aisledict = pickle.load(open("bigoven/aisleclassification.pkl", 'rb'))
    noise = pickle.load(open("bigoven/noiselist.pkl", 'rb'))
    atFM = pickle.load(open("bigoven/FMproducts.pkl", 'rb'))
    FMinfo = pickle.load(open("bigoven/FMfull.pkl", 'rb'))
    ingvect = pickle.load(open("generated_data/tfidfvect_ingredients.pkl", 'rb'))

    return w2vm, aisledict, noise, atFM, FMinfo

def request_comparison(userinput):
    mykey = open('spoonac/apikey.txt').read().strip()
    params = {'url': userinput, 'forceExtraction': 'true', 'apiKey': mykey, 'analyze': 'true'}
    response = requests.get('https://api.spoonacular.com/recipes/extract', params=params)
    rec = response.json()
    ingcomp = rec['extendedIngredients']
    ingredients = [','.join([ing['name'].lower() for ing in ingcomp if ing['name'] ])]
    return ingredients[0]

def removenoise(ingredients, noise): #call on ingredients[0]
    noise_free_ing = []
    for word in ingredients.split(','):
        checked = []
        splitit = word.split()
        checked.extend(i for i in splitit if i not in noise)
        noise_free_ing.append(' '.join(checked))
    return noise_free_ing

def rulesofsimilarity(noise_free_ing, w2vm, aisledict, atFM, FMinfo):
    output = {
        'ingredient': None,
        'where_available': None,
        'unknown': None, #unknown to word2vec
        'baking': False, #true if is baking
        'spices': False, #true if spice/seasoning
        'spice_businesses': None,
        'match': None,
        'try_fresh': None,
        'store_match': None
    }

    allout = []

    for i in noise_free_ing:
        thisout = output.copy()
        thisout['ingredient'] = i
        
        highest = process.extractOne(i,atFM)
        if highest[1] >= 90:
            matchaisle = FMinfo.loc[FMinfo['TYPES OF PRODUCTS AVAILABLE'].str.contains(highest[0])]
            thebiz = matchaisle['BUSINESS NAME'].tolist()
            thisout['where_available'] = thebiz
        # print(f'{i} is available at {thebiz} ')
            
        else:
            #these are unavailable ingredients
            curaisle = aisledict.get(i)
            
            #use w2v to find similar ingredients
            try:
                similar = w2vm.wv.most_similar(i, topn=100)
                opposite = w2vm.wv.most_similar(similar[0][0], topn=1000)
                #toreplace.append(i)
            # print(f'{i} is not but ')
            except KeyError:
                thisout['unknown'] = i
    #            print(f'We have never heard of {i}, sorry about that')
                continue
                
            #get rid of baking for now
            if curaisle[0] is not None and curaisle[0] == 'Baking':
                thisout['baking'] = True
            #   print(f'{i} is a baking product, which is likely in your pantry!')
                continue
                
            #deal with the seasoning issue
            if curaisle[0] is not None and curaisle[0] == 'Spices and Seasonings':
                matchaisle = FMinfo.loc[FMinfo['aisles'] == curaisle[0].lower()]
                thebiz = matchaisle['BUSINESS NAME'].tolist()
                #print(f'Dried Spices and and seasonings are rare, you may have this in your pantry, otherwise get fresh ones at: {thebiz}\n')
                thisout['spices'] = True
                thisout['spice_businesses'] = thebiz
                continue
                
            # here is thing our algorithm thinks is similar and IS available
            item = []
            for opp in opposite:
                ophighest = process.extractOne(opp[0],atFM)
                if ophighest[1] >= 90:
                    item.append(opp[0])
                    if len(item) == 1:
                        break
            #print(f'Here is the item our algorithm thinks is most similar and is available: {item}\n')
            thisout['match'] = item
            
            # if it is something usually prepackaged, suggest making it fresh
            if curaisle[0] == 'Pasta and Rice' or curaisle[0] == 'Canned and Jarred':
                for sim in similar:
                    a = aisledict[sim[0]]
                    if a and a[0] == 'Produce':
                        trythis = sim[0]
                        thisout['try_fresh'] = trythis
                        continue
                #print(f'Canned/Jarred items are rare at the Market, but you can make this fresh using {trythis}\n')
                
                    
            if curaisle[0] is not None: 
                #if something is not available, this vendor might be able to help you
                matchaisle = FMinfo.loc[FMinfo['aisles'] == curaisle[0].lower()]
                thebiz = matchaisle['BUSINESS NAME'].tolist()
            # print(f'This list of vendors often has products similar to {i}, try asking them: {thebiz}\n')
                thisout['store_match'] = thebiz



        allout.append(thisout)
    return allout

# %%
#function call
ingredients = request_comparison(theurl)
w2vm, aisledict, noise, atFM, FMinfo = load_data()
noise_free_ing = removenoise(ingredients, noise)
allout = rulesofsimilarity(noise_free_ing, w2vm, aisledict, atFM, FMinfo)

# %%
#Output -- equivalent is written in HTML


for out in allout:
    print(out['ingredient'])
    if out['unknown']:
        print('This is a new ingredient to us, sorry, we are learning more all the time!')
        continue
    if out['where_available']:
        print(f'is available at {out["where_available"]}\n')
        continue
    if out['baking']:
        print('is a baking item that we suspect you have in your pantry\n')
        continue
    if out['spices']:
        print(' Dried Spices and and seasonings are rare at the farmers market' + 
              f' you may have this in your pantry, otherwise check out the fresh herbs at: {out["spice_businesses"]}')
        continue
    if out['match']:
        print(f'is not available, but our algorithm thinks {out["match"]} is similar and available')
        if out['try_fresh']:
            print(f'Or you can try to make this from scratch using {out["try_fresh"]} which is available')
        
        if out['store_match']:
            print('Or, sometimes vendors do not update us on what they have today, try asking at ' +
                  f'these stores, who often have items similar to {out["ingredient"]}: {out["store_match"]}\n' )
# Out:
# chicken breast
# is available at ['Abundance Acres Farm', 'Feisty Acres Inc', 'flying pig farms', 'green table farms', 'Hawthorne Valley Farm', 'Norwich Meadows Farm', "Quattro's Game Farm", 'Ramble Creek Farm', 'Sawkill Farm', 'Shannon Brook Farm', 'Stony Mountain Ranch', 'Sun Fed Beef and Pork', 'Violet Hill Farm', 'Yellow Bell Farm']
#
# bell pepper
# is not available, but our algorithm thinks ['zucchini'] is similar and available
# Or, sometimes vendors do not update us on what they have today, try asking at these stores, who often have items similar to bell pepper: ['Alewife Farm', 'Blue Oyster Cultivation', 'breezy hill orchard', 'Brooklyn Grange Rooftop Farm', 'Bulich Mushroom Co.', 'Campo Rosso Farm', 'caradonna farms', 'Cherry Lane Farms', "D'Attolico's Organic", 'Down Home Acres', 'Eckerton Hill Farm', 'Element Farms Inc', 'Evolutionary Organics', 'Feisty Acres Inc', 'Fishkill Farms', 'Fledging Crow Vegetables', 'Garden of Eve Organic Farm', 'gopal farms', 'Gorzynski Ornery Farm', 'Heritage Farm at Snug Harbor Cultural Center', 'Hillrock Distillery', 'Hoeffner Farms', "Holy Schmitt's Homemade Horseradish", 'hudson vallue organic', 'james jurr flowers', "keith's farm", "Lani's Farm", 'Liberty Farms', 'Lucky Dog Farm', 'locut grove fruit farm', 'Migliorelli Farm', 'Mountain Sweet Berry Farm', 'northshire farm', 'Norwich Meadows Farm', 'Oak Grove Plantation', 'Orchards of Concklin', 'Phillips Farm', 'quarton farm', 'Rexcroft Farms', 'Rise & Root Farm', 'Rooted Family Farm', 'row by row farm', 'S&SO Produce Farms', 'Samascott Orchards & Nine Pin Ciderworks', 'Savoie Organic Farm', 'Shushan Valley Hydro Farm', 'Solid Ground Farm', 'Stokes Farm', 'sycamore farms', 'Tamarack Hollow Farm', 'Terhune Orchards Farm & Bakery', 'Tree-Licious Orchards & Bakery', 'Troncillito Farms', 'Two Guys From Woodbridge', 'Union Square Grassman', 'VanHouten Farms', 'Wild Yarrow Farm', 'Wilklow Orchards', 'Wood Homestead']
#
# broccoli florets
# is available at ['Alewife Farm', 'Central Valley Farm', 'Cherry Lane Farms', 'Down Home Acres', 'Element Farms Inc', 'Evolutionary Organics', 'Fishkill Farms', 'Fledging Crow Vegetables', 'gopal farms', 'Hoeffner Farms', "Lani's Farm", 'Lucky Dog Farm', 'Savoie Organic Farm', 'Solid Ground Farm', 'Stokes Farm', 'Two Guys From Woodbridge', 'Union Square Grassman', 'VanHouten Farms', 'Willow Wisp Organic Farm']
#
# mushroom
# is available at ['Alewife Farm', 'Blue Oyster Cultivation', 'Bulich Mushroom Co.', 'Central Valley Farm', 'Cherry Lane Farms', 'Down Home Acres', 'Element Farms Inc', 'Evolutionary Organics', 'Fishkill Farms', 'Fledging Crow Vegetables', "Gail's Farm", 'gopal farms', 'Hoeffner Farms', "Lani's Farm", 'Lucky Dog Farm', 'Ramble Creek Farm', 'Savoie Organic Farm', 'Solid Ground Farm', 'Stokes Farm', 'Two Guys From Woodbridge', 'VanHouten Farms', 'Willow Wisp Organic Farm']
#
# oil
# is available at ['Grazin Angus Acres']
#
# garlic
# is available at ["keith's farm"]
#
# ginger
# is available at ['Alewife Farm', 'Central Valley Farm', 'Cherry Lane Farms', 'Down Home Acres', 'Element Farms Inc', 'Evolutionary Organics', 'Fishkill Farms', 'Fledging Crow Vegetables', 'gopal farms', 'Hoeffner Farms', "Lani's Farm", 'Lucky Dog Farm', 'Savoie Organic Farm', 'Solid Ground Farm', 'Stokes Farm', 'Two Guys From Woodbridge', 'VanHouten Farms', 'Willow Wisp Organic Farm']
#
# sesame oil
# is not available, but our algorithm thinks ['rice wine vinegar'] is similar and available
# Or, sometimes vendors do not update us on what they have today, try asking at these stores, who often have items similar to sesame oil: ['Kimchee Harvest / East Branch Farms']
#
# reduced sodium soy sauce
# is not available, but our algorithm thinks ['chili garlic sauce'] is similar and available
# chicken broth
# is available at ['Yellow Bell Farm']
#
# flour
# is available at ['GrowNYC Grainstand']

# %%
#grab this new ingredient list

newlist = []
for out in allout:
    if out['where_available'] or out['spices']:
        newlist.append(out['ingredient'])
    if out['match']:
        newlist.extend(out['match'])
 
print(newlist)
# Out:
# ['chicken breast', 'zucchini', 'broccoli florets', 'mushroom', 'oil', 'garlic', 'ginger', 'rice wine vinegar', 'chili garlic sauce', 'chicken broth', 'flour']

# %%
#think through how well the replacement matches in the case of bell pepper / zucchini
w2vm = pickle.load(open("bigoven/w2vmodel.pkl", 'rb'))
atFM = pickle.load(open("bigoven/FMproducts.pkl", 'rb'))
similar = w2vm.wv.most_similar('bell pepper', topn=100)
opposite = w2vm.wv.most_similar(similar[0][0], topn=1000)
#ophighest = process.extractOne(opposite[0][0],atFM)
item = []
for opp in opposite:
    ophighest = process.extractOne(opp[0],atFM)
    if ophighest[1] >= 90:
        item.append(opp[0])
        if len(item) == 1:
            break
            
print(item)
w2vm.similarity('bell pepper', 'zucchini')
# Out:
# ['zucchini']
# /opt/anaconda3/envs/insight/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: Call to deprecated `similarity` (Method will be removed in 4.0.0, use self.wv.similarity() instead).
#   app.launch_new_instance()
# 0.77954465

# %%
nning = pickle.load(open("generated_data/cleaned_ingredients.pkl", 'rb'))

# %%
nning
# Out:
# [['garam masala',
#   'coriander leaves',
#   'ginger root',
#   'turmeric',
#   'water',
#   'coriander',
#   'water',
#   'cumin',
#   'pepper',
#   'rice',
#   'tea leaves',
#   'chana dal',
#   'salt',
#   'ghee',
#   'cumin seed',
#   'onion'],
#  ['coarse polentacornmeal',
#   'fl oz milk',
#   'half stick butter',
#   'gran luchito chilli paste',
#   'pint water',
#   'salt',
#   'parmesan',
#   'ear sweetcorn use small tin',
#   'chorizo sausage',
#   'king prawns',
#   'scallion',
#   'handful coriander',
#   'egg',
#   'lime',
#   'olive oil',
#   'salt',
#   'pepper'],
#  ['pasta',
#   'shrimp',
#   'butter',
#   'parsley',
#   'pepper flakes',
#   'pepper',
#   'kosher salt',
#   'wine',
#   'garlic',
#   'parmesan cheese',
#   'lemon'],
#  ['pepper',
#   'egg',
#   'hush puppies',
#   'grain',
#   'onion',
#   'salt',
#   'salt',
#   'fish',
#   'buttermilk',
#   'baking soda',
#   'baking powder',
#   'corn flour',
#   'cayenne',
#   'fish'],
#  ['shrimp',
#   'habanero pepper',
#   'jicama',
#   'bell pepper',
#   'bell pepper',
#   'bell pepper',
#   'purple onion',
#   'tomato',
#   'lime',
#   'cilantro',
#   'tsp sea salt'],
#  ['chicken tenderloins chicken breast filets',
#   'onion',
#   'honeu barbeque sauce',
#   'sugar',
#   'powdered garlic',
#   'pepper',
#   'sea salt'],
#  ['chicken breasts',
#   'garlic',
#   'shallots',
#   'thai chilies',
#   'pepper',
#   'egg',
#   'vegetable oil',
#   'soy sauce',
#   'thai basil leaves',
#   'fish sauce',
#   'granulated sugar'],
#  ['chicken thighs',
#   'olive oil',
#   'sesame oil',
#   'coarse salt',
#   'sticky honey sauce',
#   'honey',
#   'soy sauce',
#   'sesame oil',
#   'ginger',
#   'cloves garlic',
#   'lime',
#   'onion',
#   'sesame seeds',
#   'garnish sesame seeds scallion',
#   'serve rice'],
#  ['poivron rouge',
#   'oignon',
#   'gousses dail',
#   'huile vgtale',
#   'boeuf hach',
#   'poudre de chili',
#   'coriandre moulue',
#   'cumin moulu',
#   'gingembre moulu',
#   'poivre de cayenne',
#   'mlasse',
#   'ketchup',
#   'moutarde de dijon',
#   'vinaigre de vin rouge',
#   'bote de tomates broyes',
#   'haricots rouges',
#   'sel et poivre',
#   'moutarde lancienne'],
#  ['old el paso mild enchilada sauce',
#   'wheat tortillas',
#   'precooked chicken breast',
#   'reduced fat mexican cheese',
#   'cumin',
#   'salt pepper'],
#  ['onions',
#   'garlic',
#   'zucchini',
#   'salt',
#   'parsley',
#   'bell pepper',
#   'basil',
#   'pepper',
#   'tomato wedges',
#   'eggplant',
#   'olive oil'],
#  ['beef use turkey',
#   'gluten free elbow macaroni used brown rice pasta',
#   'milk',
#   'water',
#   'cheddar cheese',
#   'cornstarch',
#   'paprkia',
#   'salt',
#   'garlic powder',
#   'onion granulated'],
#  ['calypso broth',
#   'chicken broth',
#   'clam juice',
#   'garlic',
#   'blackened seasoning',
#   'cayenne pepper',
#   'thyme',
#   'linguine',
#   'salt pepper',
#   'medium shrimp',
#   'butter',
#   'onions',
#   'calypso broth',
#   'heavy cream',
#   'linguine',
#   'roma tomatoes'],
#  ['centercut pieces beef tenderloin ask butche',
#   'extra virgin olive oil',
#   'grill seasoning recommended montreal steak seaso',
#   'roasted peppers',
#   'garlic popped skin',
#   'handful flatleaf parsley',
#   'quality olives',
#   'salt pepper',
#   'crusty bread'],
#  ['water',
#   'sugar',
#   'raspberry balsamic vinegar',
#   'lemon juice',
#   'chambord raspberry liqueur',
#   'raspberries',
#   'cornstarch',
#   'salmon',
#   'mustard',
#   'vegetable oil',
#   'salt',
#   'scallion',
#   'raspberry',
#   'pepper'],
#  ['paprika pepper',
#   'orzo',
#   'thyme leaves',
#   'onion',
#   'garlic',
#   'reduced sodium',
#   'honey',
#   'grapefruit',
#   'cornstarch',
#   'tarragon',
#   'avocado',
#   '',
#   '',
#   'olive oil',
#   'grapefruit juice'],
#  ['beef bouillon',
#   'water chestnuts',
#   'cornstarch',
#   'sugar',
#   'shrimp',
#   'onion',
#   'mushroom',
#   'water',
#   'egg',
#   'soy sauce',
#   'soy sauce',
#   'celery'],
#  ['brown crab',
#   'oz olive oil',
#   'carrot',
#   '',
#   'onion',
#   'potato',
#   'flour dusting',
#   '',
#   'breadcrumb',
#   'skinned',
#   'basil leaves',
#   'juice lemon',
#   'salt freshly pepper'],
#  ['maple syrup', 'wholeberry cranberry sauce', 'chicken breasts', 'salt'],
#  ['meat used low fat turkey mea',
#   'rotel',
#   'onion',
#   'garlic cloves',
#   'water',
#   'tbsp taco seasoning look tac',
#   'tortilla',
#   'cheese',
#   'salsa',
#   'lettuce',
#   'cream',
#   'guacamole'],
#  ['butter',
#   'shrimp',
#   'olive',
#   'sundried tomatoes',
#   'feta cheese',
#   'parsley',
#   'bonefish grill limetomatogarlic sauce',
#   'roughly sundried tomatoes',
#   'roughly tomatoes',
#   'lemon juice',
#   'lime',
#   'garlic',
#   'wine',
#   'granulated sugar',
#   'heavy cream',
#   'salt',
#   'pepper',
#   'butter'],
#  ['chicken thighs',
#   'salt',
#   'pepper freshly',
#   'rice flour',
#   'canola oil',
#   'onion',
#   'bell pepper',
#   'carrots matchstickcut',
#   'garlic',
#   'cooking spray',
#   'mushrooms presliced ounces',
#   'chicken broth fatfree lowersodium',
#   'hungarian paprika',
#   'cream reducedfat',
#   'parsley'],
#  ['eggplant', 'tomatoe paste', 'olive oil', 'garlic', 'salt'],
#  ['salt',
#   'cumin',
#   'coriander',
#   'cloves garlic',
#   'olive oil',
#   'pork loin chops',
#   'pepper'],
#  ['garlic inch cube ginger grams',
#   'garlic',
#   'cube ginger grams',
#   'onion',
#   'olive oil',
#   'butter',
#   'chicken thighs',
#   'coconut milk',
#   'cornstarch',
#   'baby corn cobs',
#   'peas vegetables choice',
#   'spice blend',
#   'pepper teaspoon cumin teaspoon gro',
#   'pepper',
#   'cumin',
#   'coriander',
#   'tumeric',
#   'salt'],
#  ['chicken breast',
#   'egg',
#   'seasoned bread crumbs',
#   'parmesan',
#   'salt',
#   'olive oil',
#   'onion',
#   'garlic cloves',
#   'basil',
#   'tomatoes',
#   'tomato paste',
#   'wholewheat spaghetti'],
#  ['steak mince',
#   'onion',
#   'pepper',
#   'potato',
#   'tomatoes',
#   'beef stock',
#   'tomato puree',
#   'paprika',
#   'garlic powdergranules',
#   'chili powder',
#   'onion powder',
#   'paprika',
#   'sea salt flakes',
#   'sauce',
#   'lime juice'],
#  ['beef chicken',
#   'enchilada sauce',
#   'taco seasoning southwest seasoning',
#   'salt',
#   'water',
#   'salsa',
#   'corn flour tortillas',
#   'cilantro',
#   'colby jack cheddar cheese'],
#  ['canola oil',
#   'lime juice',
#   'brown sugar',
#   'chipotle chile powder',
#   'garlic cloves',
#   'pound skirt steak',
#   'onion inchthick slices',
#   'plum tomatoes',
#   'bell pepper',
#   'salt',
#   'oregano',
#   'freshly pepper',
#   'cooking spray',
#   'inch corn tortillas',
#   'reducedfat cream'],
#  ['rib',
#   'rub',
#   'brown sugar',
#   'chili powder',
#   'salt',
#   'pepper',
#   'apple cider vinegar',
#   'baby rays bbq'],
#  ['chicken breasts',
#   'buffalo wing sauce',
#   'tfrozen southernstyle hash brown potatoes',
#   'ranch cheese dressing',
#   'cheddar cheese',
#   'condensed cream celery soup',
#   'corn flake crumbs panko crumbs',
#   'butter margarine'],
#  ['unrefined coconut oil',
#   'veggies used broccoli',
#   'ginger',
#   'pepper flakes',
#   'sesame seeds',
#   'quinoa',
#   'vegan teriyaki sauce',
#   'cilantro'],
#  ['onion',
#   'olives',
#   'salt',
#   'saffron',
#   'garlic',
#   'coriander leaves',
#   'chicken',
#   'olive oil',
#   'parsley',
#   'pepper',
#   'lemon'],
#  ['one serving',
#   'small carton already fajita vegetables',
#   'mushrooms',
#   'olive oil',
#   'package flavor ramen noodle soup discard',
#   'general tso stir fry sauce',
#   'onion garnish'],
#  ['olive oil',
#   'onion',
#   'garlic cloves',
#   'rosemary',
#   'pepper flakes',
#   'tomatoes puree',
#   'clam juice',
#   'wine',
#   'halibut fillets',
#   'medium shrimp',
#   'bay scallops',
#   'parsley'],
#  ['olive oil',
#   'salmon filets',
#   'cajun seasoning',
#   'salt',
#   'pepper',
#   'fruit salsa'],
#  ['olive oil',
#   'onion',
#   'pancetta',
#   'rosemary',
#   'garlic cloves',
#   'basmati rice',
#   'chicken meat broth',
#   'cannelloni beans',
#   'flat leaf parsley',
#   'parmesan cheese',
#   'lemon'],
#  ['vegetable oil',
#   'tortillas strips',
#   'lowsodium taco fajita seasoning',
#   'onion',
#   'beef',
#   'garlic',
#   'cherry tomatoes',
#   'pickled jalapenos carrots onions',
#   'cilantro',
#   'reducedfat cream',
#   'head romaine lettuce',
#   'reducedfat pepper jack cheese'],
#  ['soy sauce',
#   'brown sugar',
#   'water',
#   'garlic',
#   'onion',
#   'ginger root',
#   'pepper',
#   'oregano',
#   'pepper flakes',
#   'cayenne pepper',
#   'paprika',
#   'chicken thighs'],
#  ['chicken',
#   'salt',
#   'suggar granulated brown',
#   'rosemary',
#   'pepper corns',
#   'clove',
#   'sage',
#   'thyme',
#   'smokedpaprika',
#   'garlic powder',
#   'kosher salt',
#   'pepper',
#   'rosemary',
#   'butter',
#   'apple juice'],
#  ['broccoli',
#   'butter',
#   'velveeta cheese',
#   'cream mushroom soup',
#   'minute rice'],
#  ['avocado oil',
#   'nosaltadded mexicanstyle seasoning blend',
#   'salt',
#   'flaky fish fillets',
#   'avocado slices',
#   'pico de gallo',
#   'corn tortillas'],
#  ['vegetable oil',
#   'chicken breasts',
#   'mushrooms',
#   'garlic cloves',
#   'pasta like cellentani pasta',
#   'water',
#   'salt',
#   'pepper',
#   'basil',
#   'spinach',
#   'heavy cream',
#   'parmesan cheese',
#   'parmesan cheese garnish'],
#  ['venison back straps chops',
#   'turkey bacon',
#   'pork sausage',
#   'salt',
#   'pepper',
#   'lemon juice',
#   'garlic salt',
#   'olive oil'],
#  ['tofu',
#   'tamari soy sauce',
#   'purpose flour',
#   'paprika',
#   'salt',
#   'pepper',
#   'oil'],
#  ['old el paso taco seasoning mix',
#   'water',
#   'sriracha sauce',
#   'chicken',
#   'pillsburry glands biscuits',
#   'monterey jack cheese mexican cheese blend',
#   'cream desired'],
#  ['chicken breasts',
#   'reducedsodium tamari soy sauce',
#   'brown sugar',
#   'ginger',
#   'pepper flakes',
#   'pineapple'],
#  ['onion',
#   'carrot',
#   'beef',
#   'lime juice',
#   'cumin',
#   'kosher salt',
#   'pepper',
#   'tomato sauce',
#   'chicken broth',
#   'peas',
#   'corn',
#   'coriander',
#   'chili'],
#  ['sirloin',
#   'oil like sunflower',
#   'jus de roti',
#   'carrot',
#   'onion',
#   'garlic cloves',
#   'artichoke hearts',
#   'flour',
#   'water',
#   'lemon',
#   'small globe artichokes',
#   'butter',
#   'jardiniere de legumes',
#   'carrot',
#   'mooli',
#   'grench beans',
#   'pea',
#   'butter',
#   'flat leaf parsley',
#   'seasoning',
#   'salt',
#   'pepper'],
#  ['chicken breasts',
#   'extra wide egg noodles',
#   'broccoli florets',
#   'spinach kale mixture',
#   'beans',
#   'tomatoes',
#   'garlic',
#   'sundried tomatoes',
#   'cheese',
#   'olive oil',
#   'tequila',
#   'cajun seasoning',
#   'chipotle sauce'],
#  ['beef top sirloin steak',
#   'bulk sausage',
#   'chili beans',
#   'chili beans spicy sauce',
#   'cans tomatoes juice',
#   'tomato paste',
#   'pepper',
#   'celery',
#   'pepper',
#   'pepper',
#   'chili peppers',
#   'bacon bits',
#   'beef broth',
#   'beer',
#   'chili powder',
#   'worcestershire sauce',
#   'garlic',
#   'oregano',
#   'cumin',
#   'pepper sauce',
#   'basil',
#   'salt',
#   'pepper',
#   'cayenne pepper',
#   'paprika',
#   'sugar',
#   'corn tortilla chips fritoes',
#   'cheddar cheese'],
#  ['cream chicken soup',
#   'water',
#   'rice',
#   'onion powder',
#   'chicken breast halves',
#   'cheddar cheese'],
#  ['soy sauce',
#   'ketchup',
#   'sugar',
#   'vinegar',
#   'ginger',
#   'cornstarch',
#   'salt',
#   'water',
#   'onions',
#   'chicken breast half',
#   'pepper',
#   'vegetable oil',
#   'garlic clove'],
#  ['wheat baguette',
#   'tuna oil',
#   'olive artichoke bruschetta',
#   'sundried tomatoes',
#   'parsley',
#   'onion',
#   'arugula',
#   'rosemary thyme basil',
#   'lemon zest juice lemon',
#   'pepper',
#   'evoo',
#   'cheese blend'],
#  ['leak',
#   'butter',
#   'wine',
#   'salt pepper',
#   'whipping cream',
#   'puff pastry',
#   'salmon fillet',
#   'egg',
#   'wine sauce',
#   'wine',
#   'freshly squeezed lemon juice',
#   'shallot',
#   'whipping cream',
#   'taragon',
#   'salt pepper'],
#  ['quinoa',
#   'onion',
#   'segments',
#   '',
#   'beans',
#   'pomegranate arils pomegranate worth',
#   'corn',
#   'cilantro',
#   'salt pepper',
#   'lemon vinaigrette',
#   'need cup juice',
#   'cloves microplaned',
#   'dash sweetener agave nectar',
#   'salt pepper',
#   'extra virgin olive oil'],
#  ['beef',
#   'onion',
#   'garlic',
#   'spaghetti sauce',
#   'pepper',
#   'ricotta cheese',
#   'milk',
#   'salt',
#   'rigatoni pasta',
#   'mozzarella',
#   'parmesan cheese'],
#  ['chicken breasts',
#   'juice one orange one lime',
#   'olive oil',
#   'tsp cumin',
#   'tsp oregano',
#   'tsp chili powder',
#   'tomato paste',
#   'garlic'],
#  ['frac cups stuffing mix',
#   'beans',
#   'cream mushroom soup',
#   'cream chicken soup',
#   'milk',
#   'fried onions',
#   'colby jack cheese',
#   'cook chicken',
#   'almonds slivered',
#   'melt butter'],
#  ['pasta',
#   'shrimp',
#   'clam juice',
#   'butter',
#   'garlic',
#   'thyme',
#   'parsley',
#   'parmesan cheese freshly'],
#  ['st louis spare ribs',
#   'sugar',
#   'garlic salt',
#   'celery salt',
#   'paprika',
#   'chili powder',
#   'pepper',
#   'cinnamon',
#   'cumin',
#   'mustard',
#   'brown sugar',
#   'honey',
#   'apple juice'],
#  ['chicken breast halves',
#   'seasoning salt',
#   'bacon',
#   'mustard',
#   'honey',
#   'dukes mayonnaise',
#   'corn syrup',
#   'onion flakes',
#   'olive oil',
#   'mushrooms',
#   'colbymonterey jack cheese',
#   'onions'],
#  ['chili powder', 'onion', 'tomato sauce', 'pepper garlic', 'octopus'],
#  ['hamburger',
#   'egg',
#   'milk',
#   'parmesan',
#   'bread crumbs',
#   'onion',
#   'garlic',
#   'oregano',
#   'salt'],
#  ['egg',
#   'tomatillogreen chile salsa page cookbo',
#   'salt',
#   'panko breadcrumbs',
#   'chili powder',
#   'cumin',
#   'garlic salt',
#   'oregano',
#   'chicken breast halves',
#   'butter pieces',
#   'lettuce',
#   'cream',
#   'onion',
#   'grape small cherry tomatoes',
#   'avocados',
#   'salt',
#   'freshly pepper',
#   'sharp cheddar cheese',
#   'lime wedges'],
#  ['rice noodles brown rice noodles',
#   'canola oil',
#   'cloves garlic',
#   'savoy cabbage',
#   'carrots',
#   'egg whites',
#   'bean sprouts',
#   'zucchini',
#   'onions',
#   'cilantro',
#   'rice wine vinegar rice vinegar',
#   'lowsodium tomato paste',
#   'reserved noodle water',
#   'unsulfured molasses',
#   'lowsodium soy sauce tamari'],
#  ['chicken breasts',
#   'franks sauce',
#   'potatoes wbox grater',
#   'ranch dressingblue cheese dressing',
#   'cheddar cheese',
#   'cream chicken soup',
#   'panko'],
#  ['shrimp',
#   'sea scallops',
#   'sundried tomatoes',
#   'button mushrooms',
#   'broccoli',
#   'heavy whipping cream',
#   'parmesan cheese',
#   'garlic cloves',
#   'onion',
#   'garlic powder',
#   'pepper flakes',
#   'cayenne pepper',
#   'salt',
#   'butter',
#   'olive oil',
#   'linguine broken half cooking',
#   'parsley garnish'],
#  ['bok choy',
#   'chicken stock',
#   'oyster sauce',
#   'low sodium soy sauce',
#   'cornstarch',
#   'splenda sugar substitute',
#   'vegetable oil',
#   'garlic'],
#  ['tofu shirataki fettucine shaped noodle substitute',
#   'chicken breast',
#   'salt',
#   'pepper',
#   'garlic powder',
#   'mushroom',
#   'onion',
#   'garlic',
#   'fatfree mayonaise',
#   'reducedfat parmasean cheese',
#   'laughing cow creamy swiss cheese',
#   'spinach leaves'],
#  ['zucchini cashew sauce',
#   'cashews',
#   'garlic cloves',
#   'lemon',
#   'basil',
#   'nutritional yeast',
#   'dehydrated tomatoes',
#   'oregano',
#   'roma tomatoes',
#   'salt pepper'],
#  ['onion',
#   'balsamic vinegar',
#   'olive oil',
#   'purpose flour',
#   'beer',
#   'sausage',
#   'thyme',
#   'chicken stock'],
#  ['water',
#   'chili powder',
#   'brown sugar',
#   'cumin',
#   'cinnamon',
#   'pork shoulder roast',
#   'semisweet chocolate pieces',
#   'plum tomatoes',
#   'cilantro'],
#  ['',
#   'cheddar cheese',
#   'meat cartilage',
#   'salt',
#   'brown',
#   'butter margarine',
#   'parsley',
#   'rice mixture optional',
#   'ounces shrimp',
#   'sole flounder fillets',
#   'paprika',
#   'pepper',
#   'chicken broth',
#   'onion',
#   'home',
#   'cream mushroom soup',
#   'removed',
#   'pounds',
#   '',
#   'crab',
#   'ca',
#   'water'],
#  ['milk',
#   'egg',
#   'pork',
#   'bread crumbs',
#   'ham',
#   'glaze',
#   'brown sugar',
#   'water',
#   'vinegar',
#   'mustard',
#   'sauce',
#   'horseradish',
#   'vinegar',
#   'mustard',
#   'salt',
#   'worcestershire sauce',
#   'cayenne',
#   'paprika',
#   'whipping cream'],
#  ['chicken',
#   'rice',
#   'garlic cloves',
#   'egg',
#   'basil',
#   'onion',
#   'spring onions',
#   'chile',
#   'soy sauce',
#   'chilli sauce',
#   'oyster sauce',
#   'peanut oil'],
#  ['butter',
#   'allpurpose flour',
#   'milk room temperature',
#   'pinch freshly nutmeg',
#   'tomato sauce',
#   'salt pepper',
#   'extravirgin olive oil',
#   'chuck beef',
#   'salt pepper',
#   'ricotta cheese',
#   'egg',
#   'lasagna sheets',
#   'ounces spinach',
#   'mozzarella',
#   'freshly parmesan',
#   'extravirgin olive oil',
#   'onion',
#   'garlic',
#   'celery',
#   '',
#   'sea salt freshly pepper',
#   'tomatoes',
#   'bay leaves',
#   'butter'],
#  ['quinoa',
#   'waterlowsodium chicken stock',
#   'onion',
#   'carrot',
#   'scallion',
#   'garlic cloves',
#   'ginger',
#   'olive oil',
#   'egg',
#   'peas',
#   'teriyaki sauce',
#   'soy sauce',
#   'sesame oil'],
#  ['milk yogurt',
#   'gingerroot',
#   'cilantro plus additional garnish',
#   'chili powder',
#   'coriander',
#   'mint',
#   'olive oil',
#   'salt',
#   '',
#   'lime wedges garnish',
#   ''],
#  ['penne pasta',
#   'olive oil',
#   'wine vinegar',
#   'honey',
#   'dijon mustard',
#   'salt pepper',
#   'tomato',
#   'garlic',
#   'baby spinach',
#   'feta cheese',
#   'pine nuts',
#   'chicken tuna salmon bacon etc',
#   'onion'],
#  ['medium potato bite sized pie',
#   'lb pork',
#   'oz sausage whatever sausage',
#   'big tomatoes',
#   'oz tomatoes',
#   'big bag beans',
#   'onion',
#   'carrots',
#   'seasoning tbsp cumin',
#   'tbsp apple cider vinegar',
#   'salt pepper',
#   'kerrygold butter'],
#  ['tilapia fillets',
#   'cooking fat',
#   'onion',
#   'garlic',
#   'jalapeopeppers',
#   'tomatoes',
#   'cilantro',
#   'lime juice',
#   'sea salt freshly cracked pepper',
#   ''],
#  ['spaghetti noodles',
#   'alfredo sauce recipe',
#   'mozzarella cheese',
#   'meatballs small bag',
#   'marinara sauce used oz jar',
#   'optional parmesan oregano garnish',
#   'pint heavy cream',
#   'garlic',
#   'pepper',
#   'salt',
#   'butter',
#   'cream cheese',
#   'freshly parmesan'],
#  ['fish snapper',
#   'roma egg tomatotes',
#   'potato',
#   'onion',
#   'olive oil',
#   'garlic',
#   'chives',
#   'thyme',
#   'olives',
#   'wine',
#   'extra virgin olive oil',
#   'lemon juice',
#   'sugar',
#   'bread crumbs'],
#  ['beef', 'water', 'beef bouillion', 'soy sauce', 'bread'],
#  ['bread cubes',
#   'chicken stock',
#   'eggs',
#   'butter',
#   'celery',
#   'onions',
#   'garlic',
#   'sausage',
#   'mild sausage',
#   'parsley',
#   'pepper',
#   'pepper flakes'],
#  ['breast',
#   'salt pepper',
#   'mozzarella cheese',
#   'pork rinds',
#   'flaxseed meal',
#   'parmesan cheese',
#   'oregano',
#   'salt',
#   'pepper',
#   'pepper flakes',
#   'garlic',
#   'paprika',
#   'egg',
#   'chicken broth',
#   'olive oil',
#   'raos tomato sauce',
#   'oil',
#   'garlic',
#   'oregano',
#   'salt pepper'],
#  ['olive oil',
#   'chicken breasts',
#   'bell pepper',
#   'bell pepper',
#   'oz coconut milk like chaokoh',
#   'salsa verde like herdez jar',
#   'roughly mango',
#   'jalapeno',
#   'brown sugar',
#   'lime juice',
#   'cumin',
#   'chili powder',
#   'paprika',
#   'salt',
#   'srirachaasian chili sauce optional',
#   'cilantro'],
#  ['rice vinegar',
#   'water',
#   'tbsp reducedsodium soy sauce tamari g',
#   'tbsp honey',
#   'canola oil',
#   'ginger',
#   'garlic cloves',
#   'lb pork tenderloins',
#   'cornstarch',
#   'water',
#   'sesame seeds',
#   'onions'],
#  ['corned beef brisket',
#   'onion',
#   'baby carrots',
#   'cabbage',
#   'water',
#   'wine vinegar'],
#  ['cooking spray',
#   'package elbow macaroni',
#   'packages mild cheddar cheese',
#   'package sharp cheddar cheese',
#   'cream',
#   'cottage cheese',
#   'egg',
#   'salt pepper'],
#  ['fettucine',
#   'margarine',
#   'cloves garlic',
#   'imitation crab meat',
#   'half half',
#   'pepper',
#   'parmesan cheese'],
#  ['chicken breasts',
#   'beef deli ham',
#   'cream',
#   'condensed cream mushroom soup',
#   'bacon',
#   'oil spray'],
#  ['rosemary',
#   'salt pepper',
#   'new potatoes',
#   'onion',
#   'shortening',
#   'water',
#   'carrot',
#   'tritip beef roast'],
#  ['use ingredients whenever possible',
#   'grassfed beef',
#   'salad greens',
#   'onion',
#   'mushrooms',
#   'favorite cheese',
#   'pickles use',
#   'ketchup condiments best',
#   'mustard',
#   'mayonaise',
#   'salt pepper',
#   'ghee another healthy fat saute',
#   'optional toppings tomatoes'],
#  ['butter',
#   'leek',
#   'fatfree lesssodium chicken broth',
#   'peas',
#   'basil leaves',
#   'extravirgin olive oil',
#   'presliced mushrooms',
#   'none garlic cloves',
#   'linguine ounces pas',
#   'salt',
#   'freshly pepper',
#   'basil'],
#  ['tenders plenty tenders made another',
#   'spinach',
#   'shallot',
#   'butter',
#   'sea salt',
#   'basil',
#   'pepper flakes',
#   'nutmeg',
#   'wine',
#   'lemon juice',
#   'corn starch',
#   'milk',
#   'chicken stock',
#   'mozzarella cheese',
#   'tomatoes'],
#  ['elbow macaroni',
#   'easy melt cheese',
#   'milk',
#   'option',
#   'dogs',
#   'broccoli florets',
#   'beef',
#   'cheese'],
#  ['lemon zest',
#   'almonds',
#   'salt',
#   'chicken broth',
#   'onion',
#   'flour',
#   'cream',
#   'pepper',
#   'water',
#   'oil',
#   'rabbit',
#   'rosemary'],
#  ['pork tenderloin',
#   'parsley leaves',
#   'pistachio nuts slivered almonds',
#   'lemon peel',
#   'salt',
#   'lemon juice',
#   'mild goat cheese spinachartichoke cheese sp',
#   'baguette'],
#  ['chicken',
#   'feta cheese cup',
#   'greek yogurt',
#   'roasted peppers',
#   'kalamata olives',
#   'lemon zest',
#   'lemon juice',
#   'salt',
#   'pepper',
#   'inch flour tortillas',
#   'baby arugula spinach cups'],
#  ['tomatoes plum small inc',
#   'onions inchthick wedges',
#   'orange peel zest slivered',
#   'oil olive extra virgin',
#   'thyme leaves',
#   'salt kosher',
#   'pepper',
#   'fish cod thickcut firmfleshed fish',
#   'thyme garnish'],
#  ['beef',
#   'cheddar cheese',
#   'enchilada sauce',
#   'chili',
#   'cream',
#   'oz tomato sauce',
#   'fritos'],
#  ['butter',
#   'lamb',
#   'onions',
#   'garlic',
#   'tomato paste',
#   'wine',
#   'artichoke hearts',
#   'lemon juice',
#   'dill weed',
#   'salt',
#   'pepper'],
#  ['vegetables',
#   'chicken breast halves',
#   'deep dish pie crusts',
#   'cream chicken'],
#  ['slices dayold bread',
#   'heavy cream',
#   'butter',
#   'onion',
#   'beef',
#   'pork',
#   'egg',
#   'brown sugar optional',
#   'salt',
#   'pepper',
#   'nutmeg',
#   'allspice',
#   'ginger optional',
#   'butter',
#   'chicken broth',
#   'allpurpose flour',
#   'beef broth',
#   'container cream'],
#  ['allpurpose flour',
#   'salt',
#   'pepper',
#   'olive oil',
#   'halibut fillets',
#   'wine',
#   'lemon juice',
#   'garlic',
#   'caper',
#   'butter',
#   'salt pepper',
#   'parsley'],
#  ['chicken thighs',
#   'carrot',
#   'pepper',
#   'mushroom',
#   'garlic',
#   'seasoning',
#   'salt',
#   'pepper',
#   'tomatoes',
#   'penne pasta',
#   'parmesan cheese',
#   'flat parsley'],
#  ['vegetable oil',
#   'onion',
#   'garlic cloves',
#   'zucchini',
#   'squash',
#   'chayote squash',
#   'jicama',
#   'tomato',
#   'chili powder',
#   'cumin',
#   'cayenne pepper',
#   'salt pepper',
#   'queso asadero mexican cheese'],
#  ['pork sausages',
#   'olive oil',
#   'spring onions',
#   'garlic',
#   'ginger',
#   'chile',
#   'cabbage',
#   'carrot',
#   'soy sauce'],
#  ['beef',
#   'vine vinegar',
#   'plume',
#   'garlic',
#   'bacon',
#   'wine',
#   'onion',
#   'carrot',
#   'celery',
#   'parsley',
#   'salt',
#   'pepper',
#   'wine',
#   'tomato jam',
#   'olive oil',
#   'parmesan'],
#  ['shrimp',
#   'olive oil',
#   'honey',
#   'lime',
#   'garlic',
#   'salt',
#   'pepper',
#   'pepper flakes'],
#  ['dutch baby',
#   'egg',
#   'milk',
#   'purpose flour',
#   'tsp salt',
#   'tsp herbs de provence',
#   'parsley',
#   'oz goat cheese',
#   'butter',
#   'topping',
#   'olive oil',
#   'cherry tomatoes',
#   'onion',
#   'additional parsley garnish'],
#  ['beef',
#   'olive oil',
#   'chuck tail chuck roast',
#   'onion',
#   'celery',
#   'carrot',
#   'cloves garlic',
#   'bay leaves',
#   'sprigs thyme',
#   'water beef stock',
#   'stroganoff',
#   'cremini mushrooms',
#   'extra virgin olive oil',
#   'butter',
#   'shallot',
#   'cloves garlic',
#   'heavy cream',
#   'braising liquid',
#   'kosher salt freshly pepper',
#   'pappardelle pasta',
#   'crme fraiche',
#   'chives'],
#  ['kale',
#   'vegetable oil',
#   'salt pepper',
#   'onion',
#   'potato',
#   'garlic',
#   'darkmeat turkey',
#   'tomatoes',
#   'ketchup',
#   'worcestershire sauce',
#   'potato hamburger buns'],
#  ['garlic clove',
#   'olive oil',
#   'salt',
#   'oregano',
#   'daily chef medium shrimp',
#   'olive garden signature dressing'],
#  ['bread crumbs',
#   'turkey beef',
#   'egg',
#   'pepper',
#   'onion',
#   'worcestershire sauce',
#   'healthy choice heinz lite ketchup',
#   'campbells healthy request cream mushroom soup'],
#  ['ranch dressing mix',
#   'dressing mix',
#   'chicken gravy mix',
#   'water',
#   'chicken breast'],
#  ['spaghetti squash',
#   '',
#   'eggs',
#   'flour',
#   'style breadcrumbs',
#   'marinara sauce',
#   'mozzarella cheese',
#   'parmesan cheese',
#   'seasoning',
#   'salt',
#   'pepper',
#   'oil frying'],
#  ['chicken breast',
#   'lime',
#   'cilantro leaves',
#   'garlic',
#   'cumin',
#   'oregano',
#   'chili powder',
#   'paprika',
#   'ancho chili powder',
#   'coarse sea salt',
#   'onion',
#   'bell pepper',
#   'bell pepper',
#   'poblano pepper',
#   'olive oil',
#   'avocado',
#   'cilantro leaves',
#   'roma tomato',
#   'onion',
#   'jalapeno pepper optional',
#   'juice lime',
#   'salt'],
#  ['prosciutto omit vegetarian dish',
#   'slices sourdough bread use gluten fre',
#   'pistachios',
#   'butter',
#   'salt pepper',
#   'spaghetti use gluten free needed',
#   'brussels sprouts',
#   'sage leaves',
#   'kale torn',
#   'clove garlic',
#   'olive oil',
#   'wine sub cup pasta cooking water',
#   'goat cheese',
#   'manchego cheese',
#   'pinch pepper',
#   'arils one pomegranate optional'],
#  ['elbow macaroni',
#   'butter',
#   'flour',
#   'milk',
#   'heavy cream',
#   'mustard powder',
#   'onion powder',
#   'cayenne pepper',
#   'garlic powder',
#   'salt pepper',
#   'garlic pepper',
#   'sharp cheddar',
#   'gouda cheese',
#   'freshly parmesan cheese',
#   'packages broccoli steamer',
#   'chicken see note',
#   'topping',
#   'seasoned breadcrumbs',
#   'butter',
#   'parmesan cheese'],
#  ['chicken legs',
#   'lemon juice',
#   'olive oil',
#   'garlic cloves',
#   'chicken bouillon cubes',
#   'kosher salt',
#   'pepper',
#   'lemons'],
#  ['taco shells',
#   'vegan beef',
#   'taco seasoning',
#   'dairyfree cream',
#   'vegan cheese',
#   'lettuce',
#   'tomato'],
#  ['spaghetti noodles',
#   'alfredo sauce recipe',
#   'mozzarella cheese',
#   'meatballs small bag',
#   'marinara sauce used oz jar',
#   'optional parmesan oregano garnish',
#   'pint heavy cream',
#   'garlic',
#   'pepper',
#   'salt',
#   'butter',
#   'cream cheese',
#   'freshly parmesan'],
#  ['extravirgin olive oil',
#   'pizza dough',
#   'tomato sauce',
#   'garlic',
#   'oregano',
#   'kosher salt freshly pepper',
#   'thinly',
#   'mozzarella cheese ounces',
#   'pepperoncini',
#   'pepperoni ounces',
#   'basil leaves',
#   'package salad greens cups'],
#  ['salmon', 'wasabi mayonnaise', 'teriyaki sauce', 'furikaki seaweed'],
#  ['teaspoon mustard seeds',
#   'pods cardamoms',
#   'pods clove',
#   'inch cinnamon stick',
#   'teaspoon cumin seeds',
#   'pinch asafetida optional',
#   'medium tomatoes',
#   'teaspoon cayenne pepper powder',
#   'teaspoon cumin powder',
#   'teaspoons coriander powder',
#   'salt',
#   'medium russet potatoes',
#   'cup',
#   'teaspoons cilantro optio'],
#  ['lard',
#   'orange juice',
#   'garlic',
#   'salt',
#   'pepper corns',
#   'achiote',
#   'cumin seeds',
#   'mexican oregano'],
#  ['pork mince',
#   'onion',
#   'bamboo shoot',
#   'capcicum',
#   'ginger',
#   'salt pepper',
#   'soy sauce',
#   'sugar',
#   'tian mien jan',
#   'ra yu',
#   'coss lettuce',
#   'shiso'],
#  ['ginger',
#   'shallot',
#   'garlic',
#   'lemongrass',
#   'mirin',
#   'sake',
#   'soy sauce',
#   'grapeseed oil',
#   'kosher salt',
#   'sea bass fillets'],
#  ['g oz pasta use conchiglie pasta',
#   'salt pepper',
#   'ml tbsp olive oil',
#   'g oz pancetta bacon',
#   'leek',
#   'g oz mushrooms',
#   'ml tbsp crme frache',
#   'flat leaf parsley'],
#  ['turkey',
#   'garlic',
#   'tomatoes',
#   'tomato sauce',
#   'mozzarella cheese',
#   'parmesan cheese',
#   'spinach',
#   'roma tomato'],
#  ['package macaroni',
#   'cauliflower broccoli florets',
#   'butter',
#   'flour',
#   'milk',
#   'salt',
#   'pepper',
#   'cheddar cheese',
#   'breadcrumb'],
#  ['tuna',
#   'clean mayo greek yogurt dont mind',
#   'sprinkle dill',
#   'salt pepper needed',
#   'avocado half seed removed'],
#  ['chicken breasts',
#   'brie',
#   'cranberry sauce',
#   'thyme',
#   'courgette',
#   'olive oil',
#   'couscous',
#   'parsley'],
#  ['sockeye salmon', 'extra virgin olive oil', 'salt cracked pepper'],
#  ['wholewheat bread',
#   'broccoli pound florets stems',
#   'wheat fusilli pasta',
#   'extravirgin olive oil',
#   'onion',
#   'allpurpose flour',
#   'mustard',
#   'skim milk',
#   'partskim ricotta cheese',
#   'parmesan cheese',
#   'course salt freshly pepper'],
#  ['cream cheese',
#   'salsa',
#   'lime juice',
#   'cumin',
#   'chili powder',
#   'onion powder',
#   'garlic powder',
#   'cilantro',
#   'onions',
#   'chicken',
#   'cheddar cheese',
#   'corn tortillas',
#   'kosher salt',
#   'cooking spray'],
#  ['oz container reducedfat cream',
#   'pickled jalapeo pepper slices',
#   'cilantro',
#   'bell pepper',
#   'onions',
#   'olive oil',
#   'garlic clove',
#   'reducedfat mayonnaise',
#   'parsley',
#   'eggs lightly',
#   'sauce',
#   'old bay seasoning',
#   'lemon zest',
#   'cornbread crumbs',
#   'lump crabmeat',
#   'vegetable cooking spray'],
#  ['rotisserie chicken',
#   'rice',
#   'curry powder',
#   'kosher salt',
#   'pepper',
#   'onion',
#   'coconut milk',
#   'tomato paste',
#   'tomatoes',
#   'zucchini',
#   'basil leaves',
#   'canola oil'],
#  ['chicken breast halves lb',
#   'garlic',
#   'fatfree reducedsodium chicken broth',
#   'classic caesar dressing',
#   'parmesan cheese',
#   ''],
#  ['bell pepper',
#   'bell pepper',
#   'portabella mushrooms',
#   'garlic',
#   'wine vinager',
#   'costco goat cheese',
#   'zuchini'],
#  ['blanched hazelnuts',
#   'garlic clove',
#   'cilantro leaves tender stems',
#   'flatleaf parsley leaves tende',
#   'caper',
#   'lemon zest',
#   'olive oil',
#   'kosher salt',
#   'vegetable oil',
#   'pieces skinon salmon fillets',
#   'butter',
#   'little gem small lettuce'],
#  ['ziti sub penne pasta',
#   'olive oil',
#   'bulk sausage beef pork',
#   'onion',
#   'garlic cloves',
#   'rosemary basil',
#   'seasoning',
#   'pepper flakes',
#   'marinara sauce ounces make',
#   'mozzarella cheese',
#   'cup ricotta cheese',
#   'parmesan pecorino cheese'],
#  ['pork fillets',
#   'soy sauce',
#   'garlic cloves',
#   'ginger',
#   'five spice powder',
#   'pepper powder',
#   'honey',
#   'sesame oil'],
#  ['cider vinegar',
#   'coarseground mustard',
#   'garlic',
#   '',
#   '',
#   'brown sugar',
#   'salt',
#   'pepper',
#   'olive oil',
#   'chicken breast halves'],
#  ['stew beef',
#   'chicken thighs',
#   'sausage',
#   'salt',
#   'pepper',
#   'flour',
#   'olive oil',
#   'garlic',
#   'onion',
#   'carrot',
#   'celery',
#   'paprika',
#   'thyme',
#   'oregano',
#   'sage',
#   'bay leaf',
#   'cinnamon',
#   'nutmeg',
#   'tomato paste',
#   'sugar',
#   'wine',
#   'beef stock',
#   'peas',
#   'butter',
#   'pecorino romano cheese',
#   'russet potatoes',
#   'pecorino romano cheese',
#   'pepper',
#   'cream milk'],
#  ['racks st louis style spare ribs',
#   'jeffs original rub recipe instant download afte',
#   'foil heavy duty',
#   'full size foil pan approx x works best'],
#  ['shopeg corn',
#   'blackeyed peas',
#   'pepper',
#   'roma tomatoes',
#   'onions parts',
#   'onion',
#   'cilantro'],
#  ['olive oil',
#   'garlic clove',
#   'lemon juice',
#   'caper',
#   'lemonpepper seasoning',
#   'fat free cream',
#   'salmon fillets'],
#  ['egg',
#   'milk',
#   'savory',
#   'salt',
#   'pepper',
#   'turkey',
#   'butter crackers',
#   'mushroom',
#   'swiss cheese',
#   'onion'],
#  ['spinach',
#   'egg',
#   'muenster cheese',
#   'salt',
#   'onion',
#   'vegetable oil',
#   'pepper'],
#  ['turkey',
#   'beef',
#   'egg',
#   'low sodium soy sauce',
#   'panko bread crumbs',
#   'wheat dinner rolls'],
#  ['turkey',
#   'lightly',
#   'bread crumbs',
#   'oregano',
#   'basil leaves',
#   'onion',
#   'garlic',
#   'parmesan reggiano cheese',
#   'salt',
#   'pepper',
#   'pieces mozzarella',
#   'olive oil',
#   'spaghetti sauce',
#   'pasta'],
#  ['paprika',
#   'onion salt',
#   'celery salt',
#   'rubbed sage',
#   'garlic powder',
#   'allspice',
#   'oregano',
#   'chili powder',
#   'pepper',
#   'basil',
#   'marjoram',
#   'pounds chicken breast meat',
#   'flour',
#   'peanut oilmore'],
#  ['g norwegian salmon patties g per',
#   'butter',
#   'pepper',
#   'pickled gherkins',
#   'tomato',
#   'brush lightly teriyaki sauce',
#   'hamburger buns'],
#  ['chicken breasts', 'garlic', 'oz jar salsa', 'oz beans'],
#  ['garlic powder',
#   'chicken breasts',
#   'manicotti shells',
#   'spaghetti sauce',
#   'bulk sausage',
#   'partskim mozzarella cheese',
#   'water'],
#  ['cream cheese',
#   'pepper jack cheese',
#   'taco seasoning',
#   'chicken',
#   'tortilla',
#   'cooking spray'],
#  ['crusty sandwich bread used sourdough bread',
#   'butter spreading bread',
#   'cream cheese spread',
#   'mezzetta marinated artichoke hearts',
#   'mezzetta savory garlic spread',
#   'grilled chicken strips',
#   'mozzarella cheese',
#   'baby spinach'],
#  ['chili peppers',
#   'vegetable cooking spray',
#   'reducedfat monterey jack cheese',
#   'fullycooked nosalt turkey breast',
#   'flour',
#   'baking powder',
#   'salt',
#   'skim milk',
#   'egg',
#   'nonfat cheddar cheese'],
#  ['chili peppers smokey sauce',
#   'cream',
#   'chicken breasts',
#   'cream',
#   'baby spinach',
#   'chicken broth',
#   'salt'],
#  ['protein choice',
#   'cabbage',
#   'carrot',
#   'onions',
#   'beans',
#   'zucchini',
#   'egg',
#   'gluten free flour',
#   'xanthan gum',
#   'stock',
#   'soy sauce',
#   'vegetable oil',
#   'sesame oil'],
#  ['macaroni',
#   'cheddar cheese',
#   'evaporated milk',
#   'egg',
#   'margarine',
#   'cheddar cheese soup',
#   'milk',
#   'salt',
#   'pepper'],
#  ['garlic',
#   'ginger root',
#   'wine',
#   'sugar',
#   'salt',
#   'peppercorns',
#   'soy sauce',
#   'oil',
#   'oil',
#   'prawn'],
#  ['pork butt',
#   'brown sugar',
#   'chili powder',
#   'paprika',
#   'onion powder',
#   'garlic powder',
#   'pepper',
#   'low sodium chicken broth',
#   'tomato paste',
#   'salt'],
#  ['mei fun rice noodles',
#   'shiitake mushrooms',
#   'bell pepper',
#   'carrot',
#   'napa cabbage',
#   'broccoli florets',
#   'leeks thoroughly',
#   'turmeric powder',
#   'malaysian curry powder',
#   'salt',
#   'sugar',
#   'easpoonfresh pepper',
#   'vegetable oil',
#   'cloves garlic',
#   'shaoxing wine',
#   'water'],
#  ['beef brisket', 'hickory chips', 'rustic rub'],
#  ['beef',
#   'bell pepper',
#   'onion',
#   'corn',
#   'manwich bold sloppy joe sauce',
#   'cream cheese',
#   'cheddar cheese',
#   'tater tots',
#   'chive'],
#  ['flour',
#   'salt',
#   'pepper',
#   'chicken breasts',
#   'olive oil',
#   'onion',
#   'butter',
#   'chicken broth',
#   'lemon juice',
#   'thyme',
#   'lemon wedges',
#   'parsley'],
#  ['turkey sausage',
#   'margarine',
#   'parmesan cheese',
#   'onion',
#   'mushroom',
#   'vegetable',
#   'bell peppers',
#   'oregano'],
#  ['chicken baked ziti ingredients',
#   'pasta',
#   'chicken',
#   'alfredo sauce',
#   'mozzarella cheese',
#   'parmesan cheese',
#   'alfredo sauce ingredients',
#   'olive oil',
#   'garlic',
#   'flour',
#   'chicken broth',
#   'milk',
#   'freshlygrated parmesan cheese',
#   'salt',
#   'pepper'],
#  ['brown rice used grain',
#   'water lowsodium chicken broth see recipe',
#   'olive oil needed',
#   'chicken breast small',
#   'storebought taco seasoning mix',
#   '',
#   'onion',
#   'garlic',
#   'zucchini',
#   'corn need',
#   'salt pepper',
#   'cilantro',
#   'beans',
#   'lime wedges',
#   'optional toppings cream'],
#  ['g spaghetti',
#   'olive oil',
#   'onion',
#   'garlic clove',
#   'chilli flakes',
#   'zucchini',
#   'zest juice lemon',
#   'parsley',
#   'parmesan'],
#  ['soba noodles',
#   'medium shrimp',
#   'salt pepper',
#   'vegetable oil',
#   'snaps peas',
#   'carrot',
#   'onion',
#   'sesame seeds',
#   'reduced sodium soy sauce',
#   'rice vinegar',
#   'honey agave syrup',
#   'sesame oil',
#   'pepper'],
#  ['onion',
#   'garlic',
#   'butter',
#   'butter',
#   'flour',
#   'milk',
#   'cheese',
#   'salt pepper',
#   'oregano',
#   'worcestershire sauce',
#   'cream',
#   'corn kernels',
#   'pea',
#   'tuna brine springwater',
#   'spiral pasta',
#   'paprika',
#   'cheese'],
#  ['allpurpose flour',
#   'wheat flour',
#   'kosher salt',
#   'cup sticks butter',
#   'apple cider vinegar',
#   'ricotta',
#   'kosher salt freshly pepper',
#   'olive oil',
#   'maitake mushrooms',
#   'garlic clove',
#   'swiss chard ribs stems removed leaves',
#   'allpurpose flour parchment',
#   'egg',
#   'tender herbs flatleaf parsl',
#   'lemon zest',
#   'lemon juice',
#   'flaky sea salt maldon'],
#  ['water',
#   'peas carrots',
#   'macaroni cheese mix',
#   'salt',
#   'pepper',
#   'milk',
#   'sharp cheddar cheese'],
#  ['spaghetti noodles',
#   'alfredo sauce recipe',
#   'mozzarella cheese',
#   'meatballs small bag',
#   'marinara sauce used oz jar',
#   'optional parmesan oregano garnish',
#   'pint heavy cream',
#   'garlic',
#   'pepper',
#   'salt',
#   'butter',
#   'cream cheese',
#   'freshly parmesan'],
#  ['brown rice',
#   'water',
#   'turkey sausage links',
#   'garlic',
#   'onion',
#   'bell pepper',
#   'bell pepper',
#   'pepper',
#   'vegetable chicken broth',
#   'grape tomatoes',
#   'pimento',
#   '',
#   'cajun',
#   ''],
#  ['beef london broil steak',
#   'lemon zest',
#   'lemon juice',
#   'olive oil',
#   'sugar',
#   'onions',
#   'worcestershire sauce',
#   'dijon mustard',
#   'salt',
#   'pepper'],
#  ['coconut oil',
#   'pepper orangegreenyellow',
#   'onion',
#   'salt',
#   'garlic powder',
#   'grassfed beef',
#   'ketchup',
#   'coconut aminos',
#   'tomato paste'],
#  ['poblano peppers',
#   'olive oil',
#   'milk',
#   'water',
#   'garlic',
#   'salt',
#   'cooking grits instant',
#   'butter',
#   'mexican chorizo'],
#  ['tartar sauce',
#   'garlic',
#   'chipotle adobe sauce',
#   'mayo',
#   'scallion',
#   'lime juice',
#   'tacos',
#   'snapper fish',
#   'worcestershire sauce',
#   'garlic',
#   'salt',
#   'freshly pepper',
#   'flour',
#   'vegetable oil',
#   'flour tortillas',
#   'cucumber',
#   'arugula leaves',
#   'cilantro',
#   'zest oranges'],
#  ['pork chops',
#   'flour',
#   'garlic powder',
#   'vegetable oil',
#   'condensed cream mushroom soup',
#   'mushroom',
#   'milk',
#   'frenchfried onions'],
#  ['egg',
#   'flatleaf parsley',
#   'tsp garlic',
#   'onion',
#   'spsalt',
#   'spground pepper',
#   'seasoned bread crumbs',
#   'parmesan cheese',
#   'beef',
#   'oz jar pasta sauce'],
#  ['water',
#   'cornstarch',
#   'shallot',
#   'salt pepper',
#   'garlic',
#   'baby shrimp',
#   'cilantro leaves',
#   'extra virgin olive oil',
#   'chicken stock',
#   'evaporated milk',
#   'penne pasta',
#   'freshly reggiano'],
#  ['beef',
#   'onion',
#   'egg',
#   'ketchup',
#   'salt',
#   'pepper',
#   'oregano',
#   'worcestershire sauce',
#   'cheddar',
#   'hamburger buns'],
#  ['herb spice rub',
#   'brown sugar',
#   'paprika',
#   'chili powder',
#   'garlic powder',
#   'onion powder',
#   'coarse salt',
#   'cumin',
#   'pepper',
#   'allspice',
#   'fajitas',
#   'meat',
#   'lime juice',
#   'olive oil',
#   'peppers',
#   'peppers',
#   'poblano peppers',
#   'onions',
#   'flour tortilla',
#   'scallion',
#   'tomato',
#   'onion',
#   'cilantro',
#   'cream',
#   'salsa',
#   'pico de gallo'],
#  ['pcooking sprayp',
#   'tbsp extravirgin olive oil',
#   'onion',
#   'bell pepper',
#   'cloves garlic',
#   'cream chicken soup',
#   'cream mushroomnbsp',
#   'rotel',
#   'c chicken',
#   'chili powder',
#   'cumin',
#   'pkosher saltp',
#   'pfreshly pepperp',
#   'corn tortillas',
#   'c cheddar',
#   'c monterey jack',
#   'pfreshly cilantro'],
#  ['wheat spaghetti',
#   'shrimp',
#   'asparagus',
#   'bell pepper',
#   'pea',
#   'garlic',
#   'kosher salt',
#   'yogurt',
#   'flat leaf parsley',
#   'lemon juice',
#   'extra virgin olive oil',
#   'freshly pepper',
#   'pine nuts'],
#  ['mayonnaise',
#   'tarragon',
#   'lemon juice',
#   'flatbread',
#   'romaine',
#   'tomato',
#   'bacon',
#   'chicken breast'],
#  ['baby new potatoes',
#   'water',
#   'chicken breasts',
#   'olive oil',
#   'cream',
#   'water',
#   'lemon juice',
#   'lemon zest',
#   'wholegrain mustard',
#   'salt pepper',
#   'flat leaf parsley',
#   'broccoli florets',
#   'baby spinach'],
#  ['salad dressing mix',
#   'flour',
#   'lemon juice',
#   'salt',
#   'butter',
#   'chicken pieces',
#   '',
#   'milk',
#   'pancake mix',
#   'paprika',
#   'sage',
#   'pepper',
#   'cooking oil'],
#  ['hash browns',
#   'potatoes',
#   'onion',
#   'egg flax egg vegan option',
#   'almond flour',
#   'coconut oil',
#   'salt',
#   'pepper',
#   'salad',
#   'bunch kale',
#   'quinoa',
#   'pepper',
#   'sunflower seeds',
#   'dressing',
#   'olive oil',
#   'lemon juice',
#   'honey',
#   'pinch cayenne',
#   'salt',
#   'pepper'],
#  ['package penne pasta',
#   'onion',
#   'fennel bulb',
#   'olive oil',
#   'garlic cloves',
#   'fennel seeds',
#   'marinara sauce',
#   'packages beef meatballs',
#   'orange juice',
#   'chicken broth',
#   'firmly orange zest',
#   'bell pepper',
#   'kosher salt',
#   'torn basil',
#   'packages mozzarella cheese slices',
#   'garnish basil leaves'],
#  ['garlic juice',
#   'worcestershire sauce',
#   'salt',
#   'peanut oil',
#   'salad dressing',
#   'lemon juice',
#   'cayenne',
#   'liquid smoke',
#   'turkey dressed',
#   'onion juice'],
#  ['pork',
#   'lowsodium soy sauce',
#   'garlic cloves',
#   'ginger',
#   'long beans',
#   'canola oil',
#   'shallot thinly',
#   'shaoxing rice wine sake',
#   'kosher salt',
#   'freshly pepper',
#   'distilled vinegar'],
#  ['onion',
#   'pepper',
#   'marjoram',
#   'mushroom',
#   'beef broth',
#   'burgundy wine',
#   'chuck',
#   'butter margarine',
#   'flour',
#   'salt',
#   'thyme'],
#  ['pork shoulder',
#   'paprika',
#   'garlic powder',
#   'chili powder',
#   'kosher salt',
#   'pepper',
#   'onion',
#   'baby rays original bbq sauce'],
#  ['regular longgrain rice',
#   'oz progresso beans',
#   'chili powder',
#   'progresso chicken stock',
#   'package oz chicken breasts',
#   'oz old el paso enchilada sauce',
#   'cheddar cheese oz'],
#  ['bacon',
#   'onions',
#   'cilantro',
#   'pecan',
#   'garlic',
#   'jalapeno pepper',
#   'pepper',
#   'pesto sauce',
#   'pasta',
#   'parmesan cheese'],
#  ['arepas',
#   'pan precooked corn meal',
#   'water',
#   'salt',
#   'oil frying',
#   'avocado chickpea hummus',
#   'olive oil',
#   'chickpeas',
#   'avocado',
#   'garlic',
#   'lemon juice',
#   'salt pepper',
#   'falafel',
#   'lentils',
#   'onion',
#   'garlic',
#   'pan precooked cornmeal',
#   'cilantro',
#   'tahini sesame seed paste',
#   'baking powder',
#   'lemon juice',
#   'olive oil',
#   'cumin',
#   'salt pepper',
#   'greek yogurt',
#   'mint',
#   'sesame oil'],
#  ['', 'corned beef brisket', 'jar grain mustard', 'aluminum foil'],
#  ['dill pickle juice',
#   'pepper sauce',
#   'chicken tenderloins',
#   'allpurpose flour',
#   'salt',
#   'pepper',
#   'egg',
#   'buttermilk',
#   'olive oil',
#   'cayenne pepper',
#   'brown sugar',
#   'paprika',
#   'chili powder',
#   'garlic powder',
#   'dill pickle slices'],
#  ['links sausage',
#   'egg',
#   'freshly parmesan cheese',
#   'freshly pepper',
#   'spaghetti long pasta choice',
#   'onion'],
#  ['baking potatoes',
#   'onion wedges',
#   'cream chicken soup',
#   'chicken',
#   'basil leaves',
#   'butter',
#   'bell pepper',
#   'water'],
#  ['long grain rice',
#   'chicken stock',
#   'vegetable oil',
#   'pork sausage',
#   'clove garlic',
#   'onion',
#   'stalk celery',
#   'bell pepper',
#   'cayenne',
#   'parsley leaves',
#   'kosher'],
#  ['pork tenderloin',
#   'lard',
#   'plum',
#   'butter',
#   'wine',
#   'cream',
#   'cream',
#   'plum brandy slivovica',
#   'parsley leaves',
#   'pepper',
#   'salt'],
#  ['flatleaf parsley leaves',
#   'oregano',
#   'cumin',
#   'pepper',
#   'garlic cloves',
#   'extra virgin olive oil',
#   'halibut fillets',
#   'kosher salt',
#   'pepper',
#   'cooking spray',
#   'corn tortillas'],
#  ['canola grapeseed',
#   'onion',
#   'garlic cloves',
#   'chile powder',
#   'cumin',
#   'chipotles en adobo stem seeds discarded c',
#   'tomatoes',
#   'water lowsodium chicken vegetable broth',
#   'potatoes medium dice cups',
#   'beans cans',
#   'onions garnish optional',
#   'feta cotija cheese garnish option',
#   'tortilla chips garnish optional',
#   'lime sixths',
#   'jalapeo thinly'],
#  ['pound pork butt shoulder',
#   'paprika',
#   'pepper',
#   'cayenne',
#   'thyme',
#   'garlic powder',
#   'salt',
#   'water',
#   'sandwich buns'],
#  ['garlic',
#   'soy sauce',
#   'balsamic vinegar',
#   'ginger root',
#   'pepper flakes',
#   'pepper',
#   'sea scallops',
#   'hoisin sauce',
#   'jalapeno',
#   'scallion',
#   'apple cider',
#   'sesame oil',
#   'kosher salt'],
#  ['olive oil',
#   'onion',
#   'garlic cloves',
#   'salt pepper',
#   'farms chicken breast portions',
#   'tomatoes cherry tomatoes',
#   'mushroom',
#   '',
#   'vegetable stock',
#   'tomato paste',
#   'cilantro garnish',
#   'chili flakes optional'],
#  ['salmon filets', 'pepper', 'garlic salt', 'butter', 'lemon juice'],
#  ['bbq sauce',
#   'chicken breasts',
#   'baking potatoes',
#   'pepper',
#   'onion',
#   'olive oil',
#   'onion powder',
#   'garlic powder',
#   'cumin',
#   'salt pepper',
#   'cheddar cheese'],
#  ['chicken wings lbs',
#   'plus tbsp rice vinegar',
#   'soy sauce',
#   'tsp peppercorns',
#   'garlic cloves',
#   'bay leaves',
#   'mayonnaise',
#   'cream',
#   'cilantro',
#   'tsp garlic powder',
#   'tsp ginger',
#   'tsp kosher salt',
#   'zest lime',
#   'lime juice',
#   'tsp ancho chile powder',
#   'fuji apple inchthick slice'],
#  ['chicken tikka',
#   'cumin',
#   'coriander',
#   'cayenne pepper',
#   'table salt',
#   'chiken breast',
#   'yoghurt',
#   'vegetable oil',
#   'garlic',
#   'ginger',
#   'masala sauce',
#   'vegetable oil',
#   'onion',
#   'garlic',
#   'ginger',
#   'jalapeno',
#   'tomato paste',
#   'garam masala',
#   'tomatoes',
#   'sugar',
#   'table salt',
#   'heavy cream',
#   'cilantro',
#   'turmeric'],
#  ['beef', 'sausage meat', 'ginger', 'garlic', 'sesame oil', 'plum sauce'],
#  ['pancake',
#   'egg',
#   'water',
#   'coarse kosher salt',
#   'gochu garu',
#   'pepper',
#   'purpose flour',
#   'shrimp',
#   'onion',
#   'onions',
#   'carrot',
#   'sauce',
#   'reducedsodium soy sauce',
#   'water',
#   'asian sesame oil',
#   'lemon juice',
#   'gochu garu',
#   'vegetable oil'],
#  ['beef',
#   'taco seasoning low sod',
#   'onion',
#   'colbypepper jack cheese',
#   'cream mushroom soup low sodium',
#   'water',
#   'corn tortillas'],
#  ['onion',
#   'roma tomato',
#   'brioche buns',
#   'beef',
#   'broccoli florets',
#   'sherry vinegar',
#   'cheddar cheese',
#   'ketchup',
#   'olive oil',
#   'sugar',
#   'salt',
#   'pepper'],
#  ['medium shrimp',
#   'scallop',
#   'lump crab meat',
#   'asparagus',
#   'shallot',
#   'garlic',
#   'baby portobello mushrooms',
#   'basil',
#   'sundried tomatoes',
#   'butter',
#   'shallot',
#   'chardonnay',
#   'fat free half half',
#   'salt',
#   'cracked pepper',
#   'glutenfree linguine pasta',
#   'extra virgin olive oil'],
#  ['garlic cloves',
#   'bell pepper',
#   'ounces tomatoes',
#   '',
#   'chicken broth',
#   'onion',
#   'parmesan cheese',
#   'basil',
#   'oregano',
#   'pepper flakes like spicy',
#   'gemelli penne pasta',
#   'basil parsley'],
#  ['chilli tomato jam',
#   'olive oil',
#   'cloves garlic',
#   'tomato',
#   'worcestershire sauce',
#   'chili sauce',
#   'firmly brown sugar',
#   'cilantro',
#   'caramelized leeks',
#   'butter',
#   'leek',
#   'brown sugar',
#   'wine',
#   'steak',
#   'ribeye steaks',
#   'ciabatta bread',
#   'olive oil',
#   'arugula'],
#  ['pork chops',
#   'rosemary',
#   'thyme',
#   'kosher salt',
#   'olive oil',
#   'ginger',
#   'water',
#   'baby carrots',
#   'peaches',
#   'spice'],
#  ['kosher salt',
#   'extravirgin olive oil',
#   'garlic',
#   'zucchini',
#   'oz chicken breasts',
#   'pepper',
#   'fettucine wheat',
#   'allpurpose flour',
#   'lowfat milk',
#   'evaporated nonfat milk',
#   'parmesean',
#   'parsley'],
#  ['ingredients lowsodium chickpeas',
#   'lowsodium chickpeas',
#   'paprika saltfree chili powder',
#   'cumin',
#   'coriander',
#   'caraway seeds',
#   'garlic',
#   'lemon juice',
#   'extravirgin olive oil',
#   'tomato',
#   'slices wholegrain bread ounces total',
#   'basil leaves',
#   'cup feta',
#   'carrot medium'],
#  ['salmon filet', 'olive oil', 'salt', 'herbs want gordon recommends thyme'],
#  ['fillet mignon',
#   'bacon',
#   'toothpicks butchers twine',
#   'vegetable oil',
#   'cajun seasoning',
#   'kosher salt',
#   'coarse pepper'],
#  ['spaghetti',
#   'turkey breast',
#   'condensed cream chicken soup',
#   'water',
#   'baby portobello mushrooms',
#   'rosemary',
#   'seasoning',
#   'onion powder',
#   'garlic powder',
#   'cheese blend',
#   'reducedfat cream',
#   'parmesan cheese',
#   'parsley flakes'],
#  ['small waxy potatoes',
#   'kosher salt',
#   'olive oil',
#   'piece skinon salmon',
#   'olive oil plus drizzling',
#   'kosher salt',
#   'crme frache',
#   'chives',
#   'thinly'],
#  ['beef',
#   'onion',
#   'chili sauce',
#   'worcestershire sauce',
#   'mustard',
#   'pepper',
#   'wheat hamburger buns',
#   'american cheese',
#   'bacon',
#   'lettuce',
#   'roma tomatoes',
#   'onion'],
#  ['lamb mince',
#   'sweetcorn',
#   'celery',
#   'wine',
#   'olive oil',
#   'tomatoes',
#   'basil',
#   'tomato',
#   'tomato ketchup',
#   'balsamic vinegar'],
#  ['zucchini squash',
#   'kosher salt',
#   'tomato',
#   'extra virgin olive oil',
#   'garlic',
#   'jalapeno pepper',
#   'freshly pepper',
#   'basil',
#   'oregano'],
#  ['gammon', 'water', 'peppercorns', 'brown sugar', 'clove'],
#  ['chicken breasts',
#   'lime juice',
#   'honey',
#   'soy sauce',
#   'olive oil',
#   'garlic cloves',
#   'cilantro',
#   'salt',
#   'pepper'],
#  ['sausage',
#   'marinara sauce',
#   'mushrooms',
#   'tomatoes',
#   'cheese tortellini',
#   'mozzarella cheese'],
#  ['meat',
#   'mushroom pieces',
#   'cream mushroom soup',
#   'water',
#   'beef bouillion',
#   'herbs spices',
#   'onion',
#   'wide egg noodles',
#   'cream',
#   'purpose flour',
#   'vegetables',
#   'chili sauce'],
#  ['turkey',
#   'orange',
#   'lemon',
#   'onion',
#   'rosemary sprigs',
#   'sage sprigs',
#   'oregano sprigs',
#   'butter',
#   'herbs de provence',
#   'olive oil',
#   'salt',
#   'freshly pepper',
#   'low sodium chicken broth',
#   'purpose flour'],
#  ['chicken breasts',
#   'tomato',
#   'bacon',
#   'vegetable oil',
#   'sandwich rolls',
#   'creamy parmesan salad dressing',
#   'cajun seasoning',
#   'swiss cheese'],
#  ['cooking oil',
#   'steak thinly',
#   'freshly ginger',
#   'cloves garlic',
#   'soy sauce',
#   'sugar equivalent amount sweetener',
#   'water',
#   'broccoli florets',
#   'cornflour',
#   'freshly pepper'],
#  ['butter shortcrust pastry',
# ...
#   'bell pepper',
#   'beans',
#   'carrot',
#   'mushroom',
#   'garlic',
#   'teriyaki marinade sauce',
#   'olive oil'],
#  ['chicken breasts',
#   'barbecue sauce',
#   'cloves garlic',
#   'onion',
#   'dressing seasoning mix',
#   'brown sugar',
#   'water',
#   'worcestershire sauce',
#   'salt pepper'],
#  ['mayonnaise',
#   'crme frache',
#   'buttermilk',
#   'parsley',
#   'lemon juice',
#   'maggi seasoning sauce',
#   'garlic powder',
#   'onion powder',
#   'freshly pepper',
#   'kosher salt',
#   'allpurpose flour',
#   'eggs room temperature',
#   'panko japanese breadcrumbs',
#   'chicken breasts',
#   'vegetable oil',
#   'hothouse cucumber',
#   'radishes',
#   'distilled vinegar',
#   'pinch sugar',
#   'aleppostyle pepper serving'],
#  ['pork sausages',
#   'apples cubes',
#   'fingerling potatoes',
#   'baby carrots',
#   'onion wedges',
#   'sage leaves',
#   'rosemary',
#   'honey',
#   'olive oil',
#   'salt pepper'],
#  ['chicken breasts',
#   'purpose flour',
#   'olive oil',
#   'shallot',
#   'garlic cloves',
#   'lemon',
#   'wine',
#   'caper',
#   'artichoke hearts',
#   'chicken stock',
#   'corn starch'],
#  ['chicken breasts',
#   'cream chicken soup',
#   'cream',
#   'cheese',
#   'cooking sherry',
#   'peas carrots',
#   'peppridge farm stuffing mix'],
#  ['pork fillet',
#   'rice wine',
#   'soy sauce',
#   'cornstarch',
#   'carrot',
#   'pepper',
#   'pineapple',
#   'mushrooms',
#   'garlic',
#   'vinegar',
#   'water',
#   'pepper',
#   'soy sauce',
#   'salt',
#   'sugar',
#   'chili pepper',
#   'cornstarch',
#   'water',
#   'oil deep frying',
#   'vegetable oil'],
#  ['chicken breast', 'cream cheese', 'onion', 'bacon'],
#  ['chicken pieces totalthighs',
#   'kosher salt freshly pepper',
#   'butter',
#   'bacon',
#   'onion',
#   'garlic cloves',
#   'cremini mushrooms',
#   'wine',
#   'wholegrain mustard',
#   'cup heavy cream',
#   'cup parsley'],
#  ['chicken breast halves',
#   'tomato',
#   'parmesan cheese',
#   'seasoning oregano basil',
#   'pepper',
#   'cornflakes',
#   'seasoning oregano basil',
#   'nonstick cooking spray',
#   'spaghetti sauce',
#   'herb linguine pasta',
#   'egg',
#   'water'],
#  ['block extra tofu',
#   'c almond milk non dairy milk',
#   'apple cider vinegar',
#   'sauce',
#   'c purpose flour',
#   'salt',
#   'c panko bread crumbs',
#   'c vegan butter',
#   'tbsp olive oil',
#   'tbsp agave syrup',
#   'paprika',
#   'garlic powder'],
#  ['sea salt',
#   'pepper',
#   'paprika',
#   'garlic powder',
#   'onion powder',
#   'garlic rosemary infused olive oil',
#   'chicken breasts',
#   'stuffing',
#   'cloves garlic',
#   'shallots',
#   'sauted spinich',
#   'low sodium chicken stock',
#   'panko',
#   'dashes sundried tomatoes',
#   'wine',
#   'pecorinoromano cheese',
#   'pepper flakes',
#   'kalmata olives',
#   'lime juice',
#   'balsamic vinegar',
#   'low sodium chicken stock',
#   'couscous',
#   'couscous millet',
#   'onions',
#   'capers',
#   'pine nuts',
#   'cranberries',
#   'sea salt',
#   'pepper',
#   'oregano',
#   'low sodium chicken stock per package direc',
#   'topping',
#   'nonfat greek yogurt',
#   'honey',
#   'lemon juice',
#   'lemon zest'],
#  ['beef',
#   'collard leaves',
#   'salt pepper',
#   'zaatar',
#   'tomato',
#   'baba ghanouj',
#   'parsley evoo garnish'],
#  ['vegetable oil',
#   'chicken breasts',
#   'water chestnuts',
#   'mushrooms',
#   'onion',
#   'baby corn',
#   'garlic',
#   'iceberg lettuce',
#   'special sauce top',
#   'sugar',
#   'water',
#   'soy sauce',
#   'rice wine vinegar',
#   'ketchup',
#   'lemon juice',
#   'sesame oil',
#   'mustard',
#   'garlic chile paste',
#   'stir fry sauce',
#   'soy sauce',
#   'brown sugar',
#   'rice wine vinegar',
#   'salt',
#   'pepper'],
#  ['pork tenderloins',
#   'balsamic vinegar',
#   'extra virgin olive oil',
#   'garlic cracked',
#   'steak seasoning blend coarse salt pep',
#   'rosemary',
#   'thyme'],
#  ['oil olive extravirgin',
#   'beef round steak',
#   'onion',
#   'carrot',
#   'mushroom',
#   'garlic',
#   'rosemary',
#   'wine',
#   'tomatoes',
#   'tomato paste',
#   'salt',
#   'peppercorn'],
#  ['rice', 'extra sharp cheddar cheese', 'kielbasa sausage'],
#  ['beef brisket',
#   'meat tenderizer',
#   'celery salt',
#   'seasoned salt',
#   'garlic salt',
#   'liquid smoke flavoring',
#   'worcestershire sauce',
#   'barbecue sauce'],
#  ['sheets cm round rice paper',
#   'prawnsshrimp cm length',
#   'vermicelli noodles',
#   'lettuce leaves use lettuce leaves',
#   'mint leaves',
#   'bean sprouts',
#   'smooth peanut butter',
#   'sugar',
#   'hoisin sauce',
#   'soy sauce see notes',
#   'garlic cloves',
#   'birds eye chilli',
#   'sesame oil',
#   'lime juice',
#   'water'],
#  ['celery stalk',
#   'carrot',
#   'cauliflower',
#   'bell pepper',
#   'onion chives',
#   'cream cheese spread',
#   'salmon',
#   'cucumber',
#   'tomato',
#   'flour tortillas',
#   'lettuce leaves'],
#  ['iceberg lettuce',
#   'sesame oil',
#   'chilli',
#   'ginger',
#   'peanut',
#   'water chestnuts',
#   'garlic',
#   'spring onions',
#   'pork',
#   'carrot',
#   'lime juice',
#   'fish sauce',
#   'soy sauce',
#   'oyster sauce',
#   'coriander',
#   'bean sprouts'],
#  ['brussels sprouts',
#   'olive oil',
#   'coarse salt',
#   'short pasta bowties',
#   'butter',
#   'parmesan cheese',
#   'grainy mustard',
#   'honey drizzling'],
#  ['canola oil',
#   'onion',
#   'garlic cloves',
#   'round',
#   'chili powder',
#   'cumin',
#   'kosher salt',
#   'longgrain rice',
#   'petitecut tomatoes jalapeos',
#   'beans',
#   'reducedfat sharp cheddar cheese'],
#  ['onion',
#   'garlic cloves',
#   'butter',
#   'tomato',
#   'brown sugar',
#   'soy sauce',
#   'rice vinegar',
#   'chili paste garlic'],
#  ['beef roast',
#   'carrot',
#   'potato',
#   'marinade',
#   'onion',
#   'brown sugar',
#   'lemon juice',
#   'bourbon',
#   'worcestershire sauce',
#   'soy sauce',
#   'salt pepper',
#   'water'],
#  ['pillsbury crescent rolls',
#   'cream cheese',
#   'margarine',
#   'chicken',
#   'salt',
#   'pepper',
#   'crouton'],
#  ['vegetable oil',
#   'onion',
#   'chicken',
#   'del monte beans',
#   'college inn chicken broth',
#   'instant rice',
#   'oregano',
#   'pepper',
#   'sharp cheddar cheese'],
#  ['pork tenderloin',
#   'coconut milk',
#   'chipotle chiles adobo sauce',
#   'pineapple',
#   'cilantro',
#   'soy sauce',
#   'russet potatoes',
#   'olive oil',
#   'chorizo'],
#  ['olive oil',
#   'chicken breast halves',
#   'garlic',
#   'cooking wine',
#   'italianstyle tomatoes',
#   'small seashell pasta',
#   'spinach',
#   'mozzarella cheese'],
#  ['apricot jam',
#   'honey mustard',
#   'garlic',
#   'soy sauce',
#   'olive oil',
#   'rosemary',
#   'leg lamb',
#   'wine',
#   'beef stock',
#   'salt',
#   'pepper'],
#  ['cod',
#   'double cream',
#   'tagliatelle',
#   'shallot',
#   'saffron threads',
#   'prawn',
#   'butter',
#   'salt',
#   'vegetable stock',
#   'wine',
#   'garlic',
#   'courgette'],
#  ['filets oz',
#   'garlic',
#   'butter tbsp cooking spray',
#   'lemon juice',
#   'parsley',
#   'oregano',
#   'salt pepper',
#   'cooking spray'],
#  ['beef turkey',
#   'oats old fashioned',
#   'egg',
#   'tomato sauce',
#   'chilies',
#   'onion',
#   'onion',
#   'chili pepper',
#   'salt',
#   'garlic powder',
#   'cheddar cheese'],
#  ['spaghetti noodles',
#   'alfredo sauce recipe',
#   'mozzarella cheese',
#   'meatballs small bag',
#   'marinara sauce used oz jar',
#   'optional parmesan oregano garnish',
#   'pint heavy cream',
#   'garlic',
#   'pepper',
#   'salt',
#   'butter',
#   'cream cheese',
#   'freshly parmesan'],
#  ['extravirgin olive oil',
#   'cup onion',
#   'pinch pepper',
#   'garlic cloves',
#   'potatoes',
#   'shrimp',
#   'coarsely kale leaves',
#   'salt pepper'],
#  ['saltine crackers',
#   'sole',
#   'garlic powder',
#   'butter',
#   'parmesan cheese',
#   'basil leaves'],
#  ['rice',
#   'tomato',
#   'chicken',
#   'beans',
#   'flour tortillas',
#   'sharp cheddar cheese'],
#  ['oive oil',
#   'onion',
#   'bell pepper',
#   'sea salt',
#   'pepper',
#   'flour',
#   'chipotle powder',
#   'salt pepper',
#   'chicken',
#   'corn tortillas'],
#  ['onion',
#   'vegetable oil',
#   'butter plus cup butter',
#   'chicken broth',
#   'clam juice',
#   'bay scallops',
#   'small shrimp',
#   'imitation crabmeat',
#   'pepper',
#   'allpurpose flour',
#   'milk',
#   'salt',
#   'whipping cream',
#   'parmesan cheese',
#   'lasagna noodles'],
#  ['chicken thighs',
#   '',
#   'onion',
#   'garlic',
#   'box either cherry grape tomatoes',
#   'freshly pepper',
#   'salt',
#   'olive oil needed'],
#  ['chicken', 'pepper', 'sage leaves', 'water', 'broccoli', 'margarine'],
#  ['elbow macaroni cup',
#   'cheese cup',
#   'milk cup',
#   'butter tbsp',
#   'salt tsp',
#   'flour tsp',
#   'pepper',
#   'parsley tsp',
#   'bread crumbs cup optional'],
#  ['zucchini',
#   'loaded cup carrots',
#   'cloves garlic',
#   'inch ginger',
#   'chili use cayenne',
#   'chickpea',
#   'cumin seeds',
#   'coriander seeds',
#   'pepper corns pepper',
#   'cinnamon',
#   'cardamom',
#   'tsp salt depends chickpeas',
#   'flax seed meal chia seed meal',
#   'oat flour flour',
#   'tbsp breadcrumbs flour',
#   'oil needed'],
#  ['chicken',
#   'breast',
#   'cornstarch',
#   'chicken stock',
#   'garlic',
#   'water chestnuts',
#   'bamboo shoots',
#   'salt',
#   'sugar',
#   'soy sauce',
#   'water',
#   'sesame oil',
#   'marinade',
#   'sherry sake',
#   'salt',
#   'sesame oil',
#   'egg',
#   'nutrition facts',
#   'amount per serving',
#   'calories',
#   'calories fat',
#   'percent total calories',
#   'fat',
#   'protein',
#   'carbohydrate',
#   'totals percent daily',
#   'value',
#   'calories fat g',
#   'saturated',
#   'fat g cholesterol mg',
#   'sodium',
#   'mg total carbohydrate g',
#   'dietary fiber g sugars',
#   'g',
#   'protein g vitamin',
#   'unit',
#   'vitamin c units',
#   'calcium',
#   'units iron units'],
#  ['patty',
#   'paprika',
#   'egg',
#   'breadcrumb',
#   'beef mince',
#   'worcestershire sauce',
#   'soy sauce',
#   'tomato sauce',
#   'chilli',
#   'salt pepper',
#   'onion',
#   'wine vinegar',
#   'canola oil',
#   'cheddar cheese',
#   'burger',
#   'bun',
#   'bacon',
#   'tomato',
#   'caramalised onion',
#   'beetroot',
#   'lettuce',
#   'sauce'],
#  ['pepper flakes',
#   'clams',
#   'water',
#   'salt pepper',
#   'clam',
#   'garlic',
#   'parsley',
#   'linguine',
#   'wine',
#   'olive oil',
#   'garlic'],
#  ['hummus cilantro',
#   'onion slices',
#   'plum tomatoes',
#   'cucumber',
#   'alfalfa sprouts',
#   'avocado',
#   'feta cheese',
#   'favorite bread'],
#  ['onion',
#   'inch piece ginger root',
#   'inch cinnamon stick preferably vietnamese cassi',
#   'star anise',
#   'cloves',
#   'teaspoon coriander seeds',
#   'cups vegetable stock',
#   'teaspoons soy sauce',
#   'carrots coarsely',
#   'pound flat rice noodles known bnh p',
#   'protein fried baked tofu bean curd ski',
#   'vegetables bok choy napa cabbage broc',
#   'onion thinly',
#   'scallions thinly',
#   'chile pepper thai bird serrano jalapeo',
#   'lime wedges',
#   'cup bean sprouts',
#   'handful herbs cilantro thai basil cula'],
#  ['allpurpose flour',
#   'egg',
#   'seasoned bread crumbs',
#   'parmesan cheese',
#   '',
#   'salt',
#   'pepper',
#   'olive oil',
#   'rolls',
#   'provolone cheese',
#   'marinara meatless pasta sauce'],
#  ['oregano',
#   'salt pepper',
#   'kitchen boquet optional',
#   'cream',
#   'dove breasts',
#   'oz cream celery',
#   'oz mushrooms',
#   'sauterne',
#   'rosemary',
#   'onion',
#   'thyme',
#   '',
#   'butter'],
#  ['chicken thighs chicken thighs',
#   'salt',
#   'pepper',
#   'honey',
#   'dijon mustard',
#   'soy sauce',
#   'chicken broth',
#   'olive oil',
#   'cloves garlic',
#   'parley'],
#  ['extra virgin olive oil',
#   'balsamic vinegar vinegar',
#   'soy sauce',
#   'worcestershire sauce',
#   'uplemon juice',
#   'brown sugar',
#   'rosemary',
#   'dijon spicy brown mustard',
#   'salt',
#   'pepper',
#   'garlic powder',
#   'chicken breast lb chicken'],
#  ['garlic',
#   'chive',
#   'shrimp',
#   'cayenne pepper',
#   'butter',
#   'salt pepper',
#   'parsley'],
#  ['olive oil',
#   'beef',
#   'water',
#   'tomato puree',
#   'wine vinegar',
#   'cumin seeds',
#   'cinnamon',
#   'salt',
#   'shallot',
#   'feta cheese',
#   'pepper'],
#  ['macaroni cups',
#   'peeleddiced potatoes russets',
#   'peeleddiced carrots',
#   'onion',
#   'water preferably use liquid veggies',
#   'cashews',
#   'coconut milk',
#   'nutritional yeast flakes',
#   'lemon juice',
#   'salt',
#   'garlic powder',
#   'cayenne pepper optional',
#   'paprika'],
#  ['broccoli',
#   'wheat flour',
#   'salt pepper',
#   'mustard',
#   'milk',
#   'macaroni wheat',
#   'stilton',
#   'margarine',
#   'yogurt'],
#  ['porkchops',
#   'lemon juice',
#   'thyme',
#   'meat tenderizer',
#   'freshly pepper',
#   'extra virgin olive oil'],
#  ['ghee',
#   'potato',
#   'salt',
#   'pepper',
#   'ghee',
#   'bell pepper',
#   'onion',
#   'turkey',
#   'taco seasoning make sure sugar',
#   'egg'],
#  ['onion',
#   'garlic powder',
#   'lime',
#   'cumin',
#   'kosher salt',
#   'pepper pepper f',
#   'c olive oil',
#   'tbsp honey',
#   'plus additional leaves serving',
#   'salmon',
#   'cooking spray'],
#  ['salmon',
#   'old bay seasoning',
#   'wilted kale',
#   'kale',
#   'garlic',
#   'peppers',
#   'chicken stock',
#   'wine vinegar',
#   'cous cous',
#   'cous cous',
#   'chicken stock',
#   'onion',
#   'pepper'],
#  ['storebought puff pastry dough',
#   'ricotta cheese',
#   'garlic powder',
#   'lemon',
#   'egg',
#   'bunch asparagus',
#   'olive oil',
#   'salt freshly pepper',
#   'peas',
#   'cup mint'],
#  ['beef',
#   'garlic',
#   'c rice',
#   'tbsp butter margarine',
#   'c water',
#   'c carrot',
#   'oxo beef',
#   'parsley',
#   'onion',
#   'salt',
#   'basil',
#   'c cheese'],
#  ['linguine',
#   'broccoli florets',
#   'carrot',
#   'oil',
#   'sirloin steak',
#   'asian sesame dressing',
#   'teriyaki sauce'],
#  ['head napa cabbage',
#   '',
#   'inch knob ginger',
#   'rice wine vinegar',
#   'soy sauce',
#   'honey',
#   'cornstarch',
#   'skinon salmon fillets',
#   'kosher salt',
#   'freshly pepper',
#   'vegetable oil'],
#  ['chicken broth',
#   'tomatoes',
#   'chili powder',
#   'allpurpose flour',
#   'garlic',
#   'cumin',
#   'oregano',
#   'salt',
#   'pinch cayenne pepper',
#   'chicken breast halves'],
#  ['bow tie pasta',
#   'garlic onion spaghetti sauce',
#   'dressing mix',
#   'mozzarella cheese'],
#  ['vinegar',
#   'pepper',
#   'pepper',
#   'salt',
#   'chili powder',
#   'onion',
#   'pork loin back ribs',
#   'salt',
#   'molasses sorghum',
#   'pepper',
#   'barbeque sauce',
#   'ketchup',
#   'rub',
#   'paprika',
#   'onion powder',
#   'pepper',
#   'water'],
#  ['mushroom mixture',
#   'butter',
#   'onion',
#   'button mushrooms',
#   'steak sauce',
#   'salt',
#   'pepper',
#   'beef wellington',
#   'beef tenderloin steaks',
#   'steak sauce',
#   'salt',
#   'pepper',
#   'pastry puff',
#   'egg'],
#  ['apricot jam preserves',
#   'honey',
#   'wine',
#   'brown sugar',
#   'dijon mustard',
#   'worcestershire sauce',
#   'balsamic vinegar',
#   'yoshidas cooking sauce substitute soy sauce',
#   'paprika',
#   'pepper shownhow ever miss',
#   'ancho chile powder substitute chipotle cayenne',
#   'garlic powder',
#   'cinnamon',
#   'sage',
#   'cloves',
#   'spiral ham'],
#  ['italianstyle turkey sausage',
#   'onion',
#   'olive oil',
#   'bell pepper',
#   'balsamic vinegar',
#   'bread'],
#  ['package ziti pasta',
#   'sausage',
#   'marinara sauce',
#   'basil',
#   'cottage cheese ricotta cheese',
#   'seasoning',
#   'salt pepper',
#   'mozzarella cheese',
#   'onion',
#   'garlic'],
#  ['cup'],
#  ['shallot',
#   'half',
#   'olive oil',
#   'sauce',
#   'chanterelle mushroom',
#   'pepper',
#   'cornstarch',
#   'salt',
#   'shiitake mushroom',
#   'olive oil',
#   'onion',
#   'parmesan cheese',
#   'basil',
#   'garlic',
#   'chives',
#   'water',
#   'tomatoes lbs',
#   'leek',
#   'tomato juice',
#   'wine',
#   'ton wrappers'],
#  ['salmon fillets', 'teriyakisauce', 'olive oil', 'garlic'],
#  ['basmati rice',
#   'lamb',
#   'cinnamon',
#   'aniseed',
#   'cardamom',
#   'annasi poo',
#   'clove',
#   'ghee',
#   'coconut milk',
#   'onion',
#   'garlic paste',
#   'ginger paste',
#   'chilli',
#   'tomato',
#   'mint leaves',
#   'cilantro leaves',
#   'low fat yogurt',
#   'egg'],
#  ['butter',
#   'onion',
#   'clove garlic',
#   'pkg quorn chicken tenders',
#   'ginger',
#   'chili powder',
#   'turmeric',
#   'cinnamon',
#   'salt',
#   'milk',
#   'tomato paste',
#   'garam masala'],
#  ['parmesan',
#   'garlic',
#   'penne pasta',
#   'olive oil',
#   'tomatoes',
#   'sugar',
#   'oilpacked sundried',
#   'pepper flakes',
#   'basil',
#   'salt pepper',
#   'ricotta cheese'],
#  ['beef top loin strip steaks',
#   'bartlett anjou pears',
#   'onion wedges',
#   'salad greens arugula',
#   'walnuts',
#   'goat cheese',
#   'salt',
#   'marinade',
#   'reducedfat regular balsamic vinaigrette',
#   'maple syrup',
#   'coarse grind pepper',
#   'thyme leaves'],
#  ['skinon chicken thighs',
#   'onion',
#   'garlic',
#   'ginger',
#   'soy sauce',
#   'tangerine',
#   'freshly pepper',
#   'vegetable oil'],
#  ['head cauliflower',
#   'garlic',
#   '',
#   'peas carrots',
#   'corn',
#   'sesame oil olive oil',
#   'soy sauce'],
#  ['pork shoulder butt roast pounds',
#   'ounces apricot preserves',
#   'onion',
#   'reducedsodium soy sauce',
#   'dijon mustard',
#   'hamburger buns'],
#  ...]

# %%
#put the full ingredient list and new ing list into correct format
senting = []
senting.extend([', '.join(n) for n in nning])
newlistj = [', '.join(newlist)]

# %%
#of all the recipes we have seen, which one is most similar based on ingredients 
ingvect = pickle.load(open("generated_data/tfidfvect_ingredients.pkl", 'rb'))

ingredientfeatures = ingvect.transform(senting)
nsf = ingvect.transform(newlistj)
cosine_similarities = linear_kernel(nsf, ingredientfeatures).flatten()
related_docs_indices = cosine_similarities.argsort()[:-5:-1]
related_docs_indices
# Out:
# array([ 6794, 18672, 39654, 19037])

# %%
#now get the full recipe

mykey = open('spoonac/apikey.txt').read().strip()
params = {'url': theurl, 'forceExtraction': 'true', 'apiKey': mykey, 'analyze': 'true'}
response = requests.get('https://api.spoonacular.com/recipes/extract', params=params)
rec = response.json()

# %%
#make that full recipe into a doc
rdoc = [rec['title'] + ingredients + rec['instructions']]
rdoc
# Out:
# ['Chicken & Veggie Stir-Fry Recipe by Tastychicken breast,salt,bell pepper,broccoli florets,mushroom,oil,garlic,ginger,sesame oil,reduced sodium soy sauce,brown sugar,chicken broth,flourIn a large pan on medium-high heat, add 1 tablespoon of oil.  Once the oil is hot, add chicken, season with salt and pepper, and sauté until cooked through and browned. Remove cooked chicken from pan and set aside.\n\nIn the same pan, heat 1 tablespoon of oil and add mushrooms. When the mushrooms start to soften, add broccoli florets and stir-fry until the broccoli is tender. Remove cooked mushrooms and broccoli from the pan and set aside.\n\nAdd 1 tablespoon of oil to the pan and sauté garlic and ginger until fragrant. Add the remaining sauce ingredients and stir until smooth.\n\nReturn the chicken and vegetables to the saucy pan, stir until heated through.\n\nServe with hot rice or noodles.\n\nEnjoy!']

# %%
related_docs_indices[0]
# Out:
# 6794

# %%
recvect = pickle.load(open("generated_data/tfidfvect_recipes.pkl", 'rb'))
recdoc = pickle.load(open("generated_data/full_recipedoc.pkl", 'rb'))


recfeatures = recvect.transform(recdoc)
currec = recvect.transform(rdoc)

cosine_similarities = linear_kernel(currec, recfeatures[related_docs_indices[0]]).flatten()
print(cosine_similarities)
# Out:
# [0.46344]

# %%
recdoc[related_docs_indices[0]]
# Out:
# 'Chicken, Broccoli and Snow Pea Stir Fry chicken breast broccoli florets mushroom snow peas soy sauce chicken broth sesame oil brown rice In a large skillet with cooking spray, cook chicken cubes over medium heat until cooked through (approx. 7-10 mins).\r\n\r\nRemove from pan and cook broccoli, mushrooms, and snow peas in the same pan. Cook until veggies begin to soften (approx. 6-8 minutes). \r\n\r\nAdd the chicken broth, soy sauce, sesame oil and chicken cubes to the pan. Serve over a bed of rice.'
