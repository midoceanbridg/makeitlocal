# %%
import pandas as pd
import pickle

# %%
GENDIR = 'eatlocal/generated_data'
atFM = pickle.load(open(f"{GENDIR}/FMproducts.pkl", 'rb')) #
FMinfo = pickle.load(open(f"{GENDIR}/FMfull.pkl", 'rb')) #

# %%
atFM
# Out:
# ['potato vodka',
#  'chicken',
#  'duck',
#  'turkey',
#  'beef',
#  'pork',
#  'eggs',
#  'maple syrup',
#  'vegetables',
#  'honey',
#  'wine',
#  'chevre',
#  'feta',
#  'mammuth',
#  'bigelo',
#  'green peppercorn',
#  'silhouette',
#  'goat cheese',
#  'doolan',
#  'pyramid',
#  'bread',
#  'jams',
#  'jellies',
#  'honey',
#  'jams',
#  'jellies',
#  'hot sauces',
#  'pickles',
#  'mushrooms',
#  'amram',
#  'baudolino',
#  'cave-aged cheddar',
#  'blue drumm',
#  'endgame',
#  'frolic',
#  'jean-louis',
#  'amish schmearkase',
#  'and amish blue',
#  'ground beef',
#  'sirloin kabob',
#  'whole tenderloin',
#  'brisket',
#  'short rib',
#  'baked goods (vegan)',
#  'wine',
#  'bread',
#  'fruits',
#  'salsa',
#  'vegetables',
#  'honey',
#  'mushrooms',
#  'chicories',
#  'lettuces',
#  'vegetables',
#  'endive',
#  'vegetables',
#  'fruit',
#  'cheese',
#  'lamb',
#  'lamb sausages',
#  'vegetables',
#  'milk',
#  'yogurt',
#  'ice cream',
#  'butter',
#  'creme fraiche',
#  'beef',
#  'pork',
#  'cheese',
#  'wine',
#  'vegetables',
#  'dairy',
#  'cheese',
#  'pork belly',
#  'tomato sauce',
#  'canned tomatoes',
#  'pickles',
#  'pasta',
#  'vegetables',
#  'fruit',
#  'maple syrup',
#  'turkey sweet sausage',
#  'turkey hot sausage',
#  'turkey burgers',
#  'turkey breakfast sausage',
#  'ground turkey',
#  'turkey steak',
#  'turkey thighs',
#  'turkey drumstick',
#  'turkey',
#  'vegetables',
#  'cider',
#  'vegetables',
#  'tomatoes',
#  'vegetables',
#  'vegetables',
#  'strawberries',
#  'blueberries',
#  'raspberries',
#  'goosberries',
#  'eggs',
#  'guinea fowl',
#  'cornish hen',
#  'chicken',
#  'quail eggs',
#  'duck eggs',
#  'silkie chicken',
#  'quail',
#  'vegetables',
#  'vegetables',
#  'pork',
#  'chicken',
#  'eggs',
#  'bread',
#  'parsley',
#  'basil',
#  'rosemary',
#  'sage',
#  'thyme',
#  'tarragon',
#  'lovage',
#  'oregano',
#  'lavender',
#  'cilantro',
#  'chives',
#  'pork',
#  'veal',
#  'vegetables',
#  'eggs',
#  'mushrooms',
#  'vegetables',
#  'meats',
#  'eggs',
#  'honey',
#  'plants',
#  'value-added',
#  'jams',
#  'pickles',
#  'dressings',
#  'pesto',
#  'vegetables',
#  'ground pork',
#  'pork chops',
#  'bacon',
#  'shoulder roast',
#  'spare ribs',
#  'rubs',
#  'tenderloin',
#  'ham steaks',
#  'smoked hocks',
#  'trotters',
#  'pork liver',
#  'pork tongue',
#  'port heart',
#  'pork tail',
#  'hot dogs',
#  'italian sausage',
#  'chorizo',
#  'breakfast sausage',
#  'ground angus',
#  'burgers',
#  'beef hot dogs',
#  'rib eye steak',
#  'ny strip steak',
#  'filet mignon',
#  'sirloin steak',
#  'flank steak',
#  'flap steak',
#  'fajita steak',
#  'london broil',
#  'stew meat',
#  'short ribs',
#  'brisket',
#  'beef liver',
#  'beef heart',
#  'marrow bones',
#  'soup bones',
#  'chicken',
#  'vegetables',
#  'fruit',
#  'grains',
#  'flour',
#  'beans',
#  'pasta',
#  'vegetables',
#  'meats',
#  'eggs',
#  'milk',
#  'beef',
#  'veal',
#  'pork',
#  'chicken',
#  'vegetables',
#  'whiskey',
#  'whiskey',
#  'vegetables',
#  'horseradish',
#  'bacon',
#  'sausage',
#  'stock pork patties',
#  'porchetta',
#  'rub roast',
#  'loin roast',
#  'sunflower oil',
#  'duck',
#  'duck breast',
#  'duck bacon',
#  'duck sausage',
#  'duck legs',
#  'duck prosciutto',
#  'duck salami',
#  'duck leg confit',
#  'smoked duck breast',
#  'duck fat',
#  'sprouts',
#  'microgreens',
#  'berries',
#  'vegetables',
#  'garlic',
#  'fruit',
#  'vegetables',
#  'kimchi; pickled vegetables',
#  'eggs',
#  'pasta',
#  'vegetables',
#  'bread',
#  'lavender',
#  'vegetables',
#  'vegetables',
#  'fruit',
#  'vegetables',
#  'meats',
#  'eggs',
#  'dairy',
#  'bread',
#  '',
#  'cheese',
#  'eggs',
#  'meats',
#  'vegetables',
#  'fruits',
#  'meats',
#  'cheese',
#  'potatoes',
#  'vegetables',
#  'honey',
#  'hard cider',
#  'vegetables',
#  'eggs',
#  'vegetables',
#  'eggs',
#  'halal chicken',
#  'vegetables',
#  'fruit',
#  'beef',
#  'pork',
#  'grains',
#  'bread',
#  'whiskey',
#  'gin',
#  'vodka',
#  'vegetables',
#  'fruit',
#  'eggs',
#  'honey',
#  'bread',
#  'vegetables',
#  'fruit',
#  'beef',
#  'pork',
#  'poultry',
#  'lamb',
#  'salsa',
#  'pasta sauce',
#  'marinara',
#  'fruits',
#  'vegetables',
#  'jams',
#  'fish',
#  'shellfish',
#  'meats',
#  'eggs',
#  'chickens',
#  'ducks',
#  'geese',
#  'turkey',
#  'pheasants',
#  'venison',
#  'pheasant eggs',
#  'turkey eggs',
#  'vegetables',
#  'beans',
#  'chicken',
#  'turkey',
#  'duck',
#  'goose',
#  'eggs and mushrooms',
#  'honey',
#  'maple products',
#  'creamed honey',
#  'pollen',
#  'beeswax',
#  'vegetables',
#  'fruit',
#  'vegetables',
#  'herbs',
#  'flowers',
#  'plants',
#  'dairy',
#  'cheese',
#  'water buffalo meat',
#  'sausages',
#  'jerky',
#  'ostrich',
#  'ostrich hot dogs',
#  'bacon',
#  'milk',
#  'yogurt',
#  'ice cream',
#  'butter',
#  'creme fraiche',
#  'vegetables',
#  'microgreens',
#  'eggs',
#  'vegetables',
#  'fruit',
#  'eggs',
#  'meats',
#  'honey',
#  'maple syrup',
#  'bread',
#  'vegetables',
#  'sauces',
#  'fruit',
#  'cider',
#  'eggs',
#  'fish',
#  'shellfish',
#  'vegetables',
#  'beef',
#  'lamb',
#  'pork',
#  'chicken',
#  'eggs',
#  'parseley',
#  'basil',
#  'rosemary',
#  'sage',
#  'thyme',
#  'tarragon',
#  'lovage',
#  'oregano',
#  'lavender',
#  'cilantro',
#  'chives',
#  'eggs',
#  'chicken',
#  'hens',
#  'peking duck',
#  'lamb chops',
#  'lamb loin',
#  'lamb rib',
#  'lamb shoulder',
#  'ground lamb',
#  'leg of lamb',
#  'rack of lamb',
#  'lamb shank',
#  'lamb shoulder',
#  'bacon',
#  'pork butt',
#  'pork chops',
#  'ribs',
#  'country-style ribs',
#  'fatback',
#  'gound pork',
#  'leaf lard',
#  'sausage',
#  'kielbasa',
#  'smoked hams',
#  'smoked hocks',
#  'bread',
#  'tomatoes',
#  'cucumbers',
#  'lettuce',
#  'arugula',
#  'chard',
#  'spinach',
#  'herbs',
#  'vegetables',
#  'vegetables',
#  'meats',
#  'beef',
#  'chicken',
#  'pork',
#  'eggs',
#  'beef. chicken',
#  'lamb',
#  'and pork',
#  'vegetables',
#  'fruit',
#  'vegetables',
#  'eggs',
#  'pork',
#  'fruit',
#  'cider',
#  'bread',
#  'cheeses',
#  'vegetables',
#  'fruit',
#  'honey',
#  'fruit',
#  'cider',
#  'vegetables',
#  'pumpkin oil',
#  'olive oil',
#  'chili oil',
#  'camelina oil',
#  'hemp oil',
#  'raps oil',
#  'sunflower greens',
#  'broccoli sprouts',
#  'pet grass',
#  'eggs',
#  'dairy',
#  'yogurt',
#  'butter',
#  'vegetables',
#  'eggs',
#  'honey',
#  'pork',
#  'rabbit',
#  'lamb',
#  'chicken',
#  'pork',
#  'lamb',
#  'goat',
#  'vegetables',
#  'fruit',
#  'cornmeal',
#  'vegetables',
#  'fruits',
#  'cider',
#  'jams',
#  'beef',
#  'pork',
#  'vegetables',
#  'maple syrup',
#  'honey',
#  'sorghum syrup',
#  'vegetables',
#  'mixed greens',
#  'herbs',
#  'microgreens',
#  'eggs',
#  'meats',
#  'eggs',
#  'chicken broth',
#  'ramps',
#  'ginger',
#  'pea greens',
#  'arugala',
#  'asparagus',
#  'chard',
#  'green onions',
#  'scallions',
#  'lattuce',
#  'mint',
#  'nettles',
#  'parsley',
#  'radishes',
#  'rhubarb',
#  'spinach',
#  'thyme',
#  'beets',
#  'broccoli',
#  'cabbage',
#  'carrots',
#  'corn',
#  'kale',
#  'kohlrabi',
#  'morels',
#  'mushrooms',
#  'oregano',
#  'strawberries',
#  'zucchini blossoms',
#  'onions']

# %%
FMinfo
# Out:
#                 BUSINESS NAME  \
# 0                1857 Spirits
# 1        Abundance Acres Farm
# 2                Alewife Farm
# 3        Andrew's Local Honey
# 4       Anthony Road Wine Co.
# ..                        ...
# 133          Wilklow Orchards
# 134  Willow Wisp Organic Farm
# 135            Wood Homestead
# 136          Wood Thrush Farm
# 137          Yellow Bell Farm
#
#                            TYPES OF PRODUCTS AVAILABLE  \
# 0                                         potato vodka
# 1    chicken, duck,  turkey, beef, pork, eggs, mapl...
# 2    onions,ramps,ginger,pea greens,arugala,asparag...
# 3                                                honey
# 4                                                 wine
# ..                                                 ...
# 133        vegetables, fruits, cider, jams, beef, pork
# 134  onions,ramps,ginger,pea greens,arugala,asparag...
# 135                  maple syrup, honey, sorghum syrup
# 136  vegetables, mixed greens, herbs, microgreens, ...
# 137                         meats, eggs, chicken broth
#
#                            aisles
# 0             alcoholic beverages
# 1                            meat
# 2                         produce
# 3    nut butters, jams, and honey
# 4             alcoholic beverages
# ..                            ...
# 133                       produce
# 134  nut butters, jams, and honey
# 135                       produce
# 136                          meat
# 137             canned and jarred
#
# [138 rows x 3 columns]
