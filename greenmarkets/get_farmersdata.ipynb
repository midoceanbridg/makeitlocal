# %%
import pandas as pd

# %%
fm = pd.read_excel('greenmarketproducts.xlsx')#, index_col=0)
fmp = fm['TYPES OF PRODUCTS AVAILABLE'].tolist()
veggies = open('juneveggies.txt').read().strip().split(',')

# %%
fm
# Out:
#                 BUSINESS NAME  \
# 0                1857 Spirits
# 1        Abundance Acres Farm
# 2                Alewife Farm
# 3        Andrew's Local Honey
# 4       Anthony Road Wine Co.
# ..                        ...
# 133          Wilklow Orchards
# 134  Willow Wisp Organic Farm
# 135            Wood Homestead
# 136          Wood Thrush Farm
# 137          Yellow Bell Farm
#
#                            TYPES OF PRODUCTS AVAILABLE  \
# 0                                         Potato Vodka
# 1    chicken, duck,  turkey, beef, pork, eggs, mapl...
# 2                                           Vegetables
# 3                                                Honey
# 4                                                 Wine
# ..                                                 ...
# 133        Vegetables, Fruits, Cider, Jams, Beef, Pork
# 134                                         Vegetables
# 135                  Maple Syrup, Honey, Sorghum Syrup
# ...

# %%
allprod = fmp+veggies
ap = [i.split(',') for i in allprod]

cleanap = []
for line in ap:
    for i in line:
        cleanap.append(i.strip().lower())

# %%
#so we want to first find if the product is availble

#IF NO
#then we want to asess if there is something in the sim/opp that is in the produce and suggest that (e.g. make your own version of canned)
#but also assess if there is a place that has the same aisle and a somewhat similar ingredient and suggest that
veggies
# Out:
# ['ramps',
#  'ginger',
#  'pea greens',
#  'arugala',
#  'asparagus',
#  'chard',
#  'green onions',
#  'scallions',
#  'lattuce',
#  'mint',
#  'nettles',
#  'parsley',
#  'radishes',
#  'rhubarb',
#  'spinach',
#  'thyme',
#  'beets',
#  'broccoli',
#  'cabbage',
#  'carrots',
#  'corn',
#  'kale',
#  'kohlrabi',
#  'morels',
#  'mushrooms',
#  'oregano',
#  'strawberries',
#  'zucchini blossoms']
